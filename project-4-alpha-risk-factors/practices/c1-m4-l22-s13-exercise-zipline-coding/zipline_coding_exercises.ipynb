# %% [markdown]
# # Zipline Coding Exercises
#
# In this notebook you will create your own pipeline and create custom factors and filters for it.

# %% [markdown]
# ### Install Packages

# %%
import sys
# !{sys.executable} -m pip install -r requirements.txt
# Out:
# Collecting graphviz==0.9
#   Using cached graphviz-0.9-py2.py3-none-any.whl (16 kB)
# Collecting numpy==1.17.0
#   Downloading numpy-1.17.0-cp36-cp36m-manylinux1_x86_64.whl (20.4 MB)
#      |████████████████████████████████| 20.4 MB 2.0 MB/s eta 0:00:01
# Collecting sqlalchemy==1.3.5
#   Downloading SQLAlchemy-1.3.5.tar.gz (5.9 MB)
#      |████████████████████████████████| 5.9 MB 8.3 MB/s eta 0:00:01
# Collecting zipline===1.3.0
#   Using cached zipline-1.3.0-cp36-cp36m-linux_x86_64.whl
# Requirement already satisfied: Logbook>=0.12.5 in /opt/conda/envs/UdacityAI/lib/python3.6/site-packages (from zipline===1.3.0->-r requirements.txt (line 4)) (1.5.3)
# Collecting bcolz<1,>=0.12.1
#   Using cached bcolz-0.12.1.tar.gz (622 kB)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/UdacityAI/lib/python3.6/site-packages (from zipline===1.3.0->-r requirements.txt (line 4)) (2.0.1)
# Requirement already satisfied: requests>=2.9.1 in /opt/conda/envs/UdacityAI/lib/python3.6/site-packages (from zipline===1.3.0->-r requirements.txt (line 4)) (2.26.0)
# Requirement already satisfied: intervaltree>=2.1.0 in /opt/conda/envs/UdacityAI/lib/python3.6/site-packages (from zipline===1.3.0->-r requirements.txt (line 4)) (3.1.0)
# Requirement already satisfied: pytz>=2016.4 in /opt/conda/envs/UdacityAI/lib/python3.6/site-packages (from zipline===1.3.0->-r requirements.txt (line 4)) (2021.1)
# Requirement already satisfied: cyordereddict>=0.2.2 in /opt/conda/envs/UdacityAI/lib/python3.6/site-packages (from zipline===1.3.0->-r requirements.txt (line 4)) (1.0.0)
# Requirement already satisfied: pandas<=0.22,>=0.18.1 in /opt/conda/envs/UdacityAI/lib/python3.6/site-packages (from zipline===1.3.0->-r requirements.txt (line 4)) (0.22.0)
# Requirement already satisfied: click>=4.0.0 in /opt/conda/envs/UdacityAI/lib/python3.6/site-packages (from zipline===1.3.0->-r requirements.txt (line 4)) (8.0.1)
# Requirement already satisfied: six>=1.10.0 in /opt/conda/envs/UdacityAI/lib/python3.6/site-packages (from zipline===1.3.0->-r requirements.txt (line 4)) (1.16.0)
# Requirement already satisfied: decorator>=4.0.0 in /opt/conda/envs/UdacityAI/lib/python3.6/site-packages (from zipline===1.3.0->-r requirements.txt (line 4)) (5.0.9)
# Requirement already satisfied: tables>=3.3.0 in /opt/conda/envs/UdacityAI/lib/python3.6/site-packages (from zipline===1.3.0->-r requirements.txt (line 4)) (3.6.1)
# Requirement already satisfied: Mako>=1.0.1 in /opt/conda/envs/UdacityAI/lib/python3.6/site-packages (from zipline===1.3.0->-r requirements.txt (line 4)) (1.1.4)
# Requirement already satisfied: scipy>=0.17.1 in /opt/conda/envs/UdacityAI/lib/python3.6/site-packages (from zipline===1.3.0->-r requirements.txt (line 4)) (1.5.4)
# Requirement already satisfied: python-dateutil>=2.4.2 in /opt/conda/envs/UdacityAI/lib/python3.6/site-packages (from zipline===1.3.0->-r requirements.txt (line 4)) (2.8.2)
# Requirement already satisfied: patsy>=0.4.0 in /opt/conda/envs/UdacityAI/lib/python3.6/site-packages (from zipline===1.3.0->-r requirements.txt (line 4)) (0.5.1)
# Requirement already satisfied: multipledispatch>=0.4.8 in /opt/conda/envs/UdacityAI/lib/python3.6/site-packages (from zipline===1.3.0->-r requirements.txt (line 4)) (0.6.0)
# Requirement already satisfied: trading-calendars>=1.0.1 in /opt/conda/envs/UdacityAI/lib/python3.6/site-packages (from zipline===1.3.0->-r requirements.txt (line 4)) (2.1.1)
# Requirement already satisfied: networkx<2.0,>=1.9.1 in /opt/conda/envs/UdacityAI/lib/python3.6/site-packages (from zipline===1.3.0->-r requirements.txt (line 4)) (1.11)
# Requirement already satisfied: statsmodels>=0.6.1 in /opt/conda/envs/UdacityAI/lib/python3.6/site-packages (from zipline===1.3.0->-r requirements.txt (line 4)) (0.12.2)
# Requirement already satisfied: requests-file>=1.4.1 in /opt/conda/envs/UdacityAI/lib/python3.6/site-packages (from zipline===1.3.0->-r requirements.txt (line 4)) (1.5.1)
# Requirement already satisfied: toolz>=0.8.2 in /opt/conda/envs/UdacityAI/lib/python3.6/site-packages (from zipline===1.3.0->-r requirements.txt (line 4)) (0.11.1)
# Requirement already satisfied: setuptools>18.0 in /opt/conda/envs/UdacityAI/lib/python3.6/site-packages (from zipline===1.3.0->-r requirements.txt (line 4)) (49.6.0.post20210108)
# Collecting alembic>=0.7.7
#   Using cached alembic-1.6.5-py2.py3-none-any.whl (164 kB)
# Requirement already satisfied: contextlib2>=0.4.0 in /opt/conda/envs/UdacityAI/lib/python3.6/site-packages (from zipline===1.3.0->-r requirements.txt (line 4)) (21.6.0)
# Requirement already satisfied: empyrical>=0.5.0 in /opt/conda/envs/UdacityAI/lib/python3.6/site-packages (from zipline===1.3.0->-r requirements.txt (line 4)) (0.5.5)
# Requirement already satisfied: sortedcontainers>=1.4.4 in /opt/conda/envs/UdacityAI/lib/python3.6/site-packages (from zipline===1.3.0->-r requirements.txt (line 4)) (2.4.0)
# Requirement already satisfied: numexpr>=2.6.1 in /opt/conda/envs/UdacityAI/lib/python3.6/site-packages (from zipline===1.3.0->-r requirements.txt (line 4)) (2.7.3)
# Requirement already satisfied: pandas-datareader>=0.2.1 in /opt/conda/envs/UdacityAI/lib/python3.6/site-packages (from zipline===1.3.0->-r requirements.txt (line 4)) (0.8.1)
# Requirement already satisfied: Cython>=0.25.2 in /opt/conda/envs/UdacityAI/lib/python3.6/site-packages (from zipline===1.3.0->-r requirements.txt (line 4)) (0.29.24)
# Requirement already satisfied: pip>=7.1.0 in /opt/conda/envs/UdacityAI/lib/python3.6/site-packages (from zipline===1.3.0->-r requirements.txt (line 4)) (21.2.3)
# Requirement already satisfied: bottleneck>=1.0.0 in /opt/conda/envs/UdacityAI/lib/python3.6/site-packages (from zipline===1.3.0->-r requirements.txt (line 4)) (1.3.2)
# Requirement already satisfied: lru-dict>=1.1.4 in /opt/conda/envs/UdacityAI/lib/python3.6/site-packages (from zipline===1.3.0->-r requirements.txt (line 4)) (1.1.7)
# Requirement already satisfied: python-editor>=0.3 in /opt/conda/envs/UdacityAI/lib/python3.6/site-packages (from alembic>=0.7.7->zipline===1.3.0->-r requirements.txt (line 4)) (1.0.4)
# Requirement already satisfied: importlib-metadata in /opt/conda/envs/UdacityAI/lib/python3.6/site-packages (from click>=4.0.0->zipline===1.3.0->-r requirements.txt (line 4)) (4.6.3)
# Requirement already satisfied: lxml in /opt/conda/envs/UdacityAI/lib/python3.6/site-packages (from pandas-datareader>=0.2.1->zipline===1.3.0->-r requirements.txt (line 4)) (4.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/UdacityAI/lib/python3.6/site-packages (from requests>=2.9.1->zipline===1.3.0->-r requirements.txt (line 4)) (2021.5.30)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/UdacityAI/lib/python3.6/site-packages (from requests>=2.9.1->zipline===1.3.0->-r requirements.txt (line 4)) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/envs/UdacityAI/lib/python3.6/site-packages (from requests>=2.9.1->zipline===1.3.0->-r requirements.txt (line 4)) (1.26.6)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/conda/envs/UdacityAI/lib/python3.6/site-packages (from requests>=2.9.1->zipline===1.3.0->-r requirements.txt (line 4)) (2.0.4)
# Requirement already satisfied: typing-extensions>=3.6.4 in /opt/conda/envs/UdacityAI/lib/python3.6/site-packages (from importlib-metadata->click>=4.0.0->zipline===1.3.0->-r requirements.txt (line 4)) (3.10.0.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/envs/UdacityAI/lib/python3.6/site-packages (from importlib-metadata->click>=4.0.0->zipline===1.3.0->-r requirements.txt (line 4)) (3.5.0)
# Building wheels for collected packages: sqlalchemy, bcolz
#   Building wheel for sqlalchemy (setup.py) ... done
#   Created wheel for sqlalchemy: filename=SQLAlchemy-1.3.5-cp36-cp36m-linux_x86_64.whl size=1188651 sha256=008d4435e0a3a637226775b645436832930fc954648013c83c96db5fbcfc499a
#   Stored in directory: /home/jovyan/.cache/pip/wheels/5b/aa/8a/fb8b032aad66db85cddded442fc984341a4044938b6248b920
#   Building wheel for bcolz (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /opt/conda/envs/UdacityAI/bin/python -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-2lq2l0gw/bcolz_7edba97160754d7f9780290eeddc1d03/setup.py'"'"'; __file__='"'"'/tmp/pip-install-2lq2l0gw/bcolz_7edba97160754d7f9780290eeddc1d03/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /tmp/pip-wheel-h931qp0b
#        cwd: /tmp/pip-install-2lq2l0gw/bcolz_7edba97160754d7f9780290eeddc1d03/
#   Complete output (83 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib.linux-x86_64-3.6
#   creating build/lib.linux-x86_64-3.6/bcolz
#   copying bcolz/py2help_tests.py -> build/lib.linux-x86_64-3.6/bcolz
#   copying bcolz/arrayprint.py -> build/lib.linux-x86_64-3.6/bcolz
#   copying bcolz/utils.py -> build/lib.linux-x86_64-3.6/bcolz
#   copying bcolz/version.py -> build/lib.linux-x86_64-3.6/bcolz
#   copying bcolz/ctable.py -> build/lib.linux-x86_64-3.6/bcolz
#   copying bcolz/toplevel.py -> build/lib.linux-x86_64-3.6/bcolz
#   copying bcolz/attrs.py -> build/lib.linux-x86_64-3.6/bcolz
#   copying bcolz/chunked_eval.py -> build/lib.linux-x86_64-3.6/bcolz
#   copying bcolz/__init__.py -> build/lib.linux-x86_64-3.6/bcolz
#   copying bcolz/defaults.py -> build/lib.linux-x86_64-3.6/bcolz
#   copying bcolz/py2help.py -> build/lib.linux-x86_64-3.6/bcolz
#   creating build/lib.linux-x86_64-3.6/bcolz/tests
#   copying bcolz/tests/all.py -> build/lib.linux-x86_64-3.6/bcolz/tests
#   copying bcolz/tests/test_ndcarray.py -> build/lib.linux-x86_64-3.6/bcolz/tests
#   copying bcolz/tests/test_ctable.py -> build/lib.linux-x86_64-3.6/bcolz/tests
#   copying bcolz/tests/common.py -> build/lib.linux-x86_64-3.6/bcolz/tests
#   copying bcolz/tests/test_attrs.py -> build/lib.linux-x86_64-3.6/bcolz/tests
#   copying bcolz/tests/test_carray_objects.py -> build/lib.linux-x86_64-3.6/bcolz/tests
#   copying bcolz/tests/test_queries.py -> build/lib.linux-x86_64-3.6/bcolz/tests
#   copying bcolz/tests/__init__.py -> build/lib.linux-x86_64-3.6/bcolz/tests
#   copying bcolz/tests/test_carray.py -> build/lib.linux-x86_64-3.6/bcolz/tests
#   copying bcolz/carray_ext.pxd -> build/lib.linux-x86_64-3.6/bcolz
#   running build_ext
#   skipping 'bcolz/carray_ext.c' Cython extension (up-to-date)
#   building 'bcolz.carray_ext' extension
#   creating build/temp.linux-x86_64-3.6
#   creating build/temp.linux-x86_64-3.6/bcolz
#   creating build/temp.linux-x86_64-3.6/c-blosc
#   creating build/temp.linux-x86_64-3.6/c-blosc/blosc
#   creating build/temp.linux-x86_64-3.6/c-blosc/internal-complibs
#   creating build/temp.linux-x86_64-3.6/c-blosc/internal-complibs/lz4-r119
#   creating build/temp.linux-x86_64-3.6/c-blosc/internal-complibs/snappy-1.1.1
#   creating build/temp.linux-x86_64-3.6/c-blosc/internal-complibs/zlib-1.2.8
#   gcc -pthread -B /opt/conda/envs/UdacityAI/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -DHAVE_LZ4=1 -DHAVE_SNAPPY=1 -DHAVE_ZLIB=1 -Ibcolz -Ic-blosc/blosc -Ic-blosc/internal-complibs/snappy-1.1.1 -Ic-blosc/internal-complibs/zlib-1.2.8 -Ic-blosc/internal-complibs/lz4-r119 -I/opt/conda/envs/UdacityAI/lib/python3.6/site-packages/numpy/core/include -I/opt/conda/envs/UdacityAI/include/python3.6m -c bcolz/carray_ext.c -o build/temp.linux-x86_64-3.6/bcolz/carray_ext.o
#   In file included from /opt/conda/envs/UdacityAI/lib/python3.6/site-packages/numpy/core/include/numpy/ndarraytypes.h:1822,
#                    from /opt/conda/envs/UdacityAI/lib/python3.6/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                    from /opt/conda/envs/UdacityAI/lib/python3.6/site-packages/numpy/core/include/numpy/arrayobject.h:4,
#                    from bcolz/carray_ext.c:242:
#   /opt/conda/envs/UdacityAI/lib/python3.6/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#      17 | #warning "Using deprecated NumPy API, disable it with " \
#         |  ^~~~~~~
#   gcc -pthread -B /opt/conda/envs/UdacityAI/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -DHAVE_LZ4=1 -DHAVE_SNAPPY=1 -DHAVE_ZLIB=1 -Ibcolz -Ic-blosc/blosc -Ic-blosc/internal-complibs/snappy-1.1.1 -Ic-blosc/internal-complibs/zlib-1.2.8 -Ic-blosc/internal-complibs/lz4-r119 -I/opt/conda/envs/UdacityAI/lib/python3.6/site-packages/numpy/core/include -I/opt/conda/envs/UdacityAI/include/python3.6m -c c-blosc/blosc/blosclz.c -o build/temp.linux-x86_64-3.6/c-blosc/blosc/blosclz.o
#   gcc -pthread -B /opt/conda/envs/UdacityAI/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -DHAVE_LZ4=1 -DHAVE_SNAPPY=1 -DHAVE_ZLIB=1 -Ibcolz -Ic-blosc/blosc -Ic-blosc/internal-complibs/snappy-1.1.1 -Ic-blosc/internal-complibs/zlib-1.2.8 -Ic-blosc/internal-complibs/lz4-r119 -I/opt/conda/envs/UdacityAI/lib/python3.6/site-packages/numpy/core/include -I/opt/conda/envs/UdacityAI/include/python3.6m -c c-blosc/blosc/shuffle.c -o build/temp.linux-x86_64-3.6/c-blosc/blosc/shuffle.o
#   gcc -pthread -B /opt/conda/envs/UdacityAI/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -DHAVE_LZ4=1 -DHAVE_SNAPPY=1 -DHAVE_ZLIB=1 -Ibcolz -Ic-blosc/blosc -Ic-blosc/internal-complibs/snappy-1.1.1 -Ic-blosc/internal-complibs/zlib-1.2.8 -Ic-blosc/internal-complibs/lz4-r119 -I/opt/conda/envs/UdacityAI/lib/python3.6/site-packages/numpy/core/include -I/opt/conda/envs/UdacityAI/include/python3.6m -c c-blosc/blosc/blosc.c -o build/temp.linux-x86_64-3.6/c-blosc/blosc/blosc.o
#   In file included from c-blosc/blosc/blosc.c:24:
#   c-blosc/internal-complibs/lz4-r119/lz4.h:179:1: warning: function declaration isn’t a prototype [-Wstrict-prototypes]
#     179 | void* LZ4_createStream();
#         | ^~~~
#   c-blosc/internal-complibs/lz4-r119/lz4.h:237:1: warning: function declaration isn’t a prototype [-Wstrict-prototypes]
#     237 | void* LZ4_createStreamDecode();
#         | ^~~~
#   gcc -pthread -B /opt/conda/envs/UdacityAI/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -DHAVE_LZ4=1 -DHAVE_SNAPPY=1 -DHAVE_ZLIB=1 -Ibcolz -Ic-blosc/blosc -Ic-blosc/internal-complibs/snappy-1.1.1 -Ic-blosc/internal-complibs/zlib-1.2.8 -Ic-blosc/internal-complibs/lz4-r119 -I/opt/conda/envs/UdacityAI/lib/python3.6/site-packages/numpy/core/include -I/opt/conda/envs/UdacityAI/include/python3.6m -c c-blosc/internal-complibs/lz4-r119/lz4.c -o build/temp.linux-x86_64-3.6/c-blosc/internal-complibs/lz4-r119/lz4.o
#   In file included from c-blosc/internal-complibs/lz4-r119/lz4.c:163:
#   c-blosc/internal-complibs/lz4-r119/lz4.h:179:1: warning: function declaration isn’t a prototype [-Wstrict-prototypes]
#     179 | void* LZ4_createStream();
#         | ^~~~
#   c-blosc/internal-complibs/lz4-r119/lz4.h:237:1: warning: function declaration isn’t a prototype [-Wstrict-prototypes]
#     237 | void* LZ4_createStreamDecode();
#         | ^~~~
#   c-blosc/internal-complibs/lz4-r119/lz4.c:687:7: warning: function declaration isn’t a prototype [-Wstrict-prototypes]
#     687 | void* LZ4_createStream()
#         |       ^~~~~~~~~~~~~~~~
#   c-blosc/internal-complibs/lz4-r119/lz4.c:1077:7: warning: function declaration isn’t a prototype [-Wstrict-prototypes]
#    1077 | void* LZ4_createStreamDecode()
#         |       ^~~~~~~~~~~~~~~~~~~~~~
#   gcc -pthread -B /opt/conda/envs/UdacityAI/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -DHAVE_LZ4=1 -DHAVE_SNAPPY=1 -DHAVE_ZLIB=1 -Ibcolz -Ic-blosc/blosc -Ic-blosc/internal-complibs/snappy-1.1.1 -Ic-blosc/internal-complibs/zlib-1.2.8 -Ic-blosc/internal-complibs/lz4-r119 -I/opt/conda/envs/UdacityAI/lib/python3.6/site-packages/numpy/core/include -I/opt/conda/envs/UdacityAI/include/python3.6m -c c-blosc/internal-complibs/lz4-r119/lz4hc.c -o build/temp.linux-x86_64-3.6/c-blosc/internal-complibs/lz4-r119/lz4hc.o
#   In file included from c-blosc/internal-complibs/lz4-r119/lz4hc.c:142:
#   c-blosc/internal-complibs/lz4-r119/lz4.h:179:1: warning: function declaration isn’t a prototype [-Wstrict-prototypes]
#     179 | void* LZ4_createStream();
#         | ^~~~
#   c-blosc/internal-complibs/lz4-r119/lz4.h:237:1: warning: function declaration isn’t a prototype [-Wstrict-prototypes]
#     237 | void* LZ4_createStreamDecode();
#         | ^~~~
#   gcc -pthread -B /opt/conda/envs/UdacityAI/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -DHAVE_LZ4=1 -DHAVE_SNAPPY=1 -DHAVE_ZLIB=1 -Ibcolz -Ic-blosc/blosc -Ic-blosc/internal-complibs/snappy-1.1.1 -Ic-blosc/internal-complibs/zlib-1.2.8 -Ic-blosc/internal-complibs/lz4-r119 -I/opt/conda/envs/UdacityAI/lib/python3.6/site-packages/numpy/core/include -I/opt/conda/envs/UdacityAI/include/python3.6m -c c-blosc/internal-complibs/snappy-1.1.1/snappy.cc -o build/temp.linux-x86_64-3.6/c-blosc/internal-complibs/snappy-1.1.1/snappy.o
#   gcc: fatal error: cannot execute ‘cc1plus’: execvp: No such file or directory
#   compilation terminated.
#   error: command 'gcc' failed with exit status 1
#   ----------------------------------------
#   ERROR: Failed building wheel for bcolz
#   Running setup.py clean for bcolz
# Successfully built sqlalchemy
# Failed to build bcolz
# Installing collected packages: numpy, sqlalchemy, bcolz, alembic, zipline, graphviz
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 1.4.22
#     Uninstalling SQLAlchemy-1.4.22:
#       Successfully uninstalled SQLAlchemy-1.4.22
#     Running setup.py install for bcolz ... error
#     ERROR: Command errored out with exit status 1:
#      command: /opt/conda/envs/UdacityAI/bin/python -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-2lq2l0gw/bcolz_7edba97160754d7f9780290eeddc1d03/setup.py'"'"'; __file__='"'"'/tmp/pip-install-2lq2l0gw/bcolz_7edba97160754d7f9780290eeddc1d03/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /tmp/pip-record-53w1ki62/install-record.txt --single-version-externally-managed --compile --install-headers /opt/conda/envs/UdacityAI/include/python3.6m/bcolz
#          cwd: /tmp/pip-install-2lq2l0gw/bcolz_7edba97160754d7f9780290eeddc1d03/
#     Complete output (83 lines):
#     running install
#     running build
#     running build_py
#     creating build
#     creating build/lib.linux-x86_64-3.6
#     creating build/lib.linux-x86_64-3.6/bcolz
#     copying bcolz/py2help_tests.py -> build/lib.linux-x86_64-3.6/bcolz
#     copying bcolz/arrayprint.py -> build/lib.linux-x86_64-3.6/bcolz
#     copying bcolz/utils.py -> build/lib.linux-x86_64-3.6/bcolz
#     copying bcolz/version.py -> build/lib.linux-x86_64-3.6/bcolz
#     copying bcolz/ctable.py -> build/lib.linux-x86_64-3.6/bcolz
#     copying bcolz/toplevel.py -> build/lib.linux-x86_64-3.6/bcolz
#     copying bcolz/attrs.py -> build/lib.linux-x86_64-3.6/bcolz
#     copying bcolz/chunked_eval.py -> build/lib.linux-x86_64-3.6/bcolz
#     copying bcolz/__init__.py -> build/lib.linux-x86_64-3.6/bcolz
#     copying bcolz/defaults.py -> build/lib.linux-x86_64-3.6/bcolz
#     copying bcolz/py2help.py -> build/lib.linux-x86_64-3.6/bcolz
#     creating build/lib.linux-x86_64-3.6/bcolz/tests
#     copying bcolz/tests/all.py -> build/lib.linux-x86_64-3.6/bcolz/tests
#     copying bcolz/tests/test_ndcarray.py -> build/lib.linux-x86_64-3.6/bcolz/tests
#     copying bcolz/tests/test_ctable.py -> build/lib.linux-x86_64-3.6/bcolz/tests
#     copying bcolz/tests/common.py -> build/lib.linux-x86_64-3.6/bcolz/tests
#     copying bcolz/tests/test_attrs.py -> build/lib.linux-x86_64-3.6/bcolz/tests
#     copying bcolz/tests/test_carray_objects.py -> build/lib.linux-x86_64-3.6/bcolz/tests
#     copying bcolz/tests/test_queries.py -> build/lib.linux-x86_64-3.6/bcolz/tests
#     copying bcolz/tests/__init__.py -> build/lib.linux-x86_64-3.6/bcolz/tests
#     copying bcolz/tests/test_carray.py -> build/lib.linux-x86_64-3.6/bcolz/tests
#     copying bcolz/carray_ext.pxd -> build/lib.linux-x86_64-3.6/bcolz
#     running build_ext
#     skipping 'bcolz/carray_ext.c' Cython extension (up-to-date)
#     building 'bcolz.carray_ext' extension
#     creating build/temp.linux-x86_64-3.6
#     creating build/temp.linux-x86_64-3.6/bcolz
#     creating build/temp.linux-x86_64-3.6/c-blosc
#     creating build/temp.linux-x86_64-3.6/c-blosc/blosc
#     creating build/temp.linux-x86_64-3.6/c-blosc/internal-complibs
#     creating build/temp.linux-x86_64-3.6/c-blosc/internal-complibs/lz4-r119
#     creating build/temp.linux-x86_64-3.6/c-blosc/internal-complibs/snappy-1.1.1
#     creating build/temp.linux-x86_64-3.6/c-blosc/internal-complibs/zlib-1.2.8
#     gcc -pthread -B /opt/conda/envs/UdacityAI/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -DHAVE_LZ4=1 -DHAVE_SNAPPY=1 -DHAVE_ZLIB=1 -Ibcolz -Ic-blosc/blosc -Ic-blosc/internal-complibs/snappy-1.1.1 -Ic-blosc/internal-complibs/zlib-1.2.8 -Ic-blosc/internal-complibs/lz4-r119 -I/opt/conda/envs/UdacityAI/lib/python3.6/site-packages/numpy/core/include -I/opt/conda/envs/UdacityAI/include/python3.6m -c bcolz/carray_ext.c -o build/temp.linux-x86_64-3.6/bcolz/carray_ext.o
#     In file included from /opt/conda/envs/UdacityAI/lib/python3.6/site-packages/numpy/core/include/numpy/ndarraytypes.h:1830,
#                      from /opt/conda/envs/UdacityAI/lib/python3.6/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                      from /opt/conda/envs/UdacityAI/lib/python3.6/site-packages/numpy/core/include/numpy/arrayobject.h:4,
#                      from bcolz/carray_ext.c:242:
#     /opt/conda/envs/UdacityAI/lib/python3.6/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#        17 | #warning "Using deprecated NumPy API, disable it with " \
#           |  ^~~~~~~
#     gcc -pthread -B /opt/conda/envs/UdacityAI/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -DHAVE_LZ4=1 -DHAVE_SNAPPY=1 -DHAVE_ZLIB=1 -Ibcolz -Ic-blosc/blosc -Ic-blosc/internal-complibs/snappy-1.1.1 -Ic-blosc/internal-complibs/zlib-1.2.8 -Ic-blosc/internal-complibs/lz4-r119 -I/opt/conda/envs/UdacityAI/lib/python3.6/site-packages/numpy/core/include -I/opt/conda/envs/UdacityAI/include/python3.6m -c c-blosc/blosc/blosclz.c -o build/temp.linux-x86_64-3.6/c-blosc/blosc/blosclz.o
#     gcc -pthread -B /opt/conda/envs/UdacityAI/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -DHAVE_LZ4=1 -DHAVE_SNAPPY=1 -DHAVE_ZLIB=1 -Ibcolz -Ic-blosc/blosc -Ic-blosc/internal-complibs/snappy-1.1.1 -Ic-blosc/internal-complibs/zlib-1.2.8 -Ic-blosc/internal-complibs/lz4-r119 -I/opt/conda/envs/UdacityAI/lib/python3.6/site-packages/numpy/core/include -I/opt/conda/envs/UdacityAI/include/python3.6m -c c-blosc/blosc/shuffle.c -o build/temp.linux-x86_64-3.6/c-blosc/blosc/shuffle.o
#     gcc -pthread -B /opt/conda/envs/UdacityAI/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -DHAVE_LZ4=1 -DHAVE_SNAPPY=1 -DHAVE_ZLIB=1 -Ibcolz -Ic-blosc/blosc -Ic-blosc/internal-complibs/snappy-1.1.1 -Ic-blosc/internal-complibs/zlib-1.2.8 -Ic-blosc/internal-complibs/lz4-r119 -I/opt/conda/envs/UdacityAI/lib/python3.6/site-packages/numpy/core/include -I/opt/conda/envs/UdacityAI/include/python3.6m -c c-blosc/blosc/blosc.c -o build/temp.linux-x86_64-3.6/c-blosc/blosc/blosc.o
#     In file included from c-blosc/blosc/blosc.c:24:
#     c-blosc/internal-complibs/lz4-r119/lz4.h:179:1: warning: function declaration isn’t a prototype [-Wstrict-prototypes]
#       179 | void* LZ4_createStream();
#           | ^~~~
#     c-blosc/internal-complibs/lz4-r119/lz4.h:237:1: warning: function declaration isn’t a prototype [-Wstrict-prototypes]
#       237 | void* LZ4_createStreamDecode();
#           | ^~~~
#     gcc -pthread -B /opt/conda/envs/UdacityAI/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -DHAVE_LZ4=1 -DHAVE_SNAPPY=1 -DHAVE_ZLIB=1 -Ibcolz -Ic-blosc/blosc -Ic-blosc/internal-complibs/snappy-1.1.1 -Ic-blosc/internal-complibs/zlib-1.2.8 -Ic-blosc/internal-complibs/lz4-r119 -I/opt/conda/envs/UdacityAI/lib/python3.6/site-packages/numpy/core/include -I/opt/conda/envs/UdacityAI/include/python3.6m -c c-blosc/internal-complibs/lz4-r119/lz4.c -o build/temp.linux-x86_64-3.6/c-blosc/internal-complibs/lz4-r119/lz4.o
#     In file included from c-blosc/internal-complibs/lz4-r119/lz4.c:163:
#     c-blosc/internal-complibs/lz4-r119/lz4.h:179:1: warning: function declaration isn’t a prototype [-Wstrict-prototypes]
#       179 | void* LZ4_createStream();
#           | ^~~~
#     c-blosc/internal-complibs/lz4-r119/lz4.h:237:1: warning: function declaration isn’t a prototype [-Wstrict-prototypes]
#       237 | void* LZ4_createStreamDecode();
#           | ^~~~
#     c-blosc/internal-complibs/lz4-r119/lz4.c:687:7: warning: function declaration isn’t a prototype [-Wstrict-prototypes]
#       687 | void* LZ4_createStream()
#           |       ^~~~~~~~~~~~~~~~
#     c-blosc/internal-complibs/lz4-r119/lz4.c:1077:7: warning: function declaration isn’t a prototype [-Wstrict-prototypes]
#      1077 | void* LZ4_createStreamDecode()
#           |       ^~~~~~~~~~~~~~~~~~~~~~
#     gcc -pthread -B /opt/conda/envs/UdacityAI/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -DHAVE_LZ4=1 -DHAVE_SNAPPY=1 -DHAVE_ZLIB=1 -Ibcolz -Ic-blosc/blosc -Ic-blosc/internal-complibs/snappy-1.1.1 -Ic-blosc/internal-complibs/zlib-1.2.8 -Ic-blosc/internal-complibs/lz4-r119 -I/opt/conda/envs/UdacityAI/lib/python3.6/site-packages/numpy/core/include -I/opt/conda/envs/UdacityAI/include/python3.6m -c c-blosc/internal-complibs/lz4-r119/lz4hc.c -o build/temp.linux-x86_64-3.6/c-blosc/internal-complibs/lz4-r119/lz4hc.o
#     In file included from c-blosc/internal-complibs/lz4-r119/lz4hc.c:142:
#     c-blosc/internal-complibs/lz4-r119/lz4.h:179:1: warning: function declaration isn’t a prototype [-Wstrict-prototypes]
#       179 | void* LZ4_createStream();
#           | ^~~~
#     c-blosc/internal-complibs/lz4-r119/lz4.h:237:1: warning: function declaration isn’t a prototype [-Wstrict-prototypes]
#       237 | void* LZ4_createStreamDecode();
#           | ^~~~
#     gcc -pthread -B /opt/conda/envs/UdacityAI/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -DHAVE_LZ4=1 -DHAVE_SNAPPY=1 -DHAVE_ZLIB=1 -Ibcolz -Ic-blosc/blosc -Ic-blosc/internal-complibs/snappy-1.1.1 -Ic-blosc/internal-complibs/zlib-1.2.8 -Ic-blosc/internal-complibs/lz4-r119 -I/opt/conda/envs/UdacityAI/lib/python3.6/site-packages/numpy/core/include -I/opt/conda/envs/UdacityAI/include/python3.6m -c c-blosc/internal-complibs/snappy-1.1.1/snappy.cc -o build/temp.linux-x86_64-3.6/c-blosc/internal-complibs/snappy-1.1.1/snappy.o
#     gcc: fatal error: cannot execute ‘cc1plus’: execvp: No such file or directory
#     compilation terminated.
#     error: command 'gcc' failed with exit status 1
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: /opt/conda/envs/UdacityAI/bin/python -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-2lq2l0gw/bcolz_7edba97160754d7f9780290eeddc1d03/setup.py'"'"'; __file__='"'"'/tmp/pip-install-2lq2l0gw/bcolz_7edba97160754d7f9780290eeddc1d03/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /tmp/pip-record-53w1ki62/install-record.txt --single-version-externally-managed --compile --install-headers /opt/conda/envs/UdacityAI/include/python3.6m/bcolz Check the logs for full command output.

# %% [markdown]
# # Load Data

# %%
import os

from zipline.data import bundles
from zipline.data.bundles.csvdir import csvdir_equities


# Specify the bundle name
bundle_name = 'm4-quiz-eod-quotemedia'

# Create an ingest function 
ingest_func = csvdir_equities(['daily'], bundle_name)

# Register the data bundle and its ingest function
bundles.register(bundle_name, ingest_func);

# Set environment variable 'ZIPLINE_ROOT' to the path where the most recent data is located
os.environ['ZIPLINE_ROOT'] = os.path.join(os.getcwd(), '..', '..', 'data', 'module_4_quizzes_eod')

# Load the data bundle
bundle_data = bundles.load(bundle_name)

# %% [markdown]
# # TODO: Build an Empty Pipeline with a Screen
#
# In the code below create an empty with a screen that filters the pipeline output for stocks with a 60-day average dollar volume greater than \$50,000.

# %%
# import resources
from zipline.pipeline import Pipeline
from zipline.pipeline.factors import AverageDollarVolume

# Create a screen for our Pipeline
universe = AverageDollarVolume(window_length = 60).top(10)

# Create an empty Pipeline with the given screen
pipeline = Pipeline(screen = universe)

# %% [markdown]
# # TODO: Create a Pipeline Engine
#
# In the code below, create a data loader that loads our data bundle using Zipline's `USEquityPricingLoader`. Then create a function to be passed to the `get_loader` parameter in the pipeline engine. Using the NYSE trading calendar create a pipeline engine using Zipline's `SimplePipelineEngine`

# %%
# import resources
from zipline.pipeline.loaders import USEquityPricingLoader
from zipline.utils.calendars import get_calendar
from zipline.pipeline.data import USEquityPricing
from zipline.pipeline.engine import SimplePipelineEngine

# Set the dataloader
pricing_loader = USEquityPricingLoader(bundle_data.equity_daily_bar_reader, bundle_data.adjustment_reader)

# Define the function for the get_loader parameter
def choose_loader(column):
    if column not in USEquityPricing.columns:
        raise Exception('Column not in USEquityPricing')
    return pricing_loader

# Set the trading calendar
trading_calendar = get_calendar('NYSE')

# Create a Pipeline engine
engine = SimplePipelineEngine(get_loader = choose_loader,
                              calendar = trading_calendar.all_sessions,
                              asset_finder = bundle_data.asset_finder)

# %% [markdown]
# # TODO: Create Factors and Filters For The Pipeline
#
# ### Factors
#
# In the code below, create two factors:
#
# 1. **Custom Factor**: Create a custom factor, `percent_difference`,  by combining a 30-day average closing price factor and a 60-average closing price factor. The `percent_difference` factor will calculate the difference between the 30-day and 60-average closing price factors, and will then normalize this difference by the 60-average closing price factor.
#
#
# 2. **Daily Returns Factor**: Create a factor that returns the daily percent change in closing price. To do this, use Zipline's built-in [DailyReturns](https://zipline.ml4trading.io/api-reference.html?highlight=dailyreturns#zipline.pipeline.factors.DailyReturns) factor.
#
# Both factors should use the closing prices in the `USEquityPricing`  dataset as inputs.
#
#
#
#
# ### Filters
#
# In the code below, you will create a **Custom Filter**, `tradable_asset`, that returns `True` for the top 20 securities of average dollar volume in a 30 day-window that have a latest closing price above \$30. To do this, you will create two filters first and them combine them. For the first filter, you can use Zipline's built-in factor `AverageDollarVolume()` and its method `.top()` to select the top 20 assets of average dollar volume in a 30 day-window. To get the latest close price of the `USEquityPricing` dataset you can use `USEquityPricing.close.latest`. Finally you can combine these two filters by using the logical operator `&`.

# %%
# import resources
import pandas as pd
from zipline.pipeline.factors import SimpleMovingAverage
from zipline.pipeline.factors import DailyReturns

# Create the 30-day average closing price factor
mean_close_30 = SimpleMovingAverage(inputs = [USEquityPricing.close], window_length = 30)

# Create the 60-day average closing price factor
mean_close_60 = SimpleMovingAverage(inputs = [USEquityPricing.close], window_length = 60)

# Create the custom factor
percent_difference = (mean_close_30 - mean_close_60) / mean_close_60

# Create the daily returns factor
daily_returns = DailyReturns(inputs=[USEquityPricing.close])

# Create a filter for the top 20 securities of average dollar volume in a 30 day-window
top_20 = AverageDollarVolume(window_length=30).top(20)

# Create a filter for the latest closing price above $30
above_30 = USEquityPricing.close.latest > 30

# Create a custum filter
tradable_asset = top_20 & above_30

# %% [markdown]
# # TODO: Add Factors and Filters To The Pipeline
#
# In the code below, add the factors and filters you created above to the pipeline

# %%
# Add the custom factor to the pipeline
pipeline.add(percent_difference, 'Percent Difference')

# Add the daily returns factor to the pipeline
pipeline.add(daily_returns, 'Daily Return')

# Add the custom filter to the pipeline
pipeline.add(tradable_asset, 'Tradable')

# %% [markdown]
# # TODO: Run The Pipeline
#
# In the code below, run the pipeline for the dates given

# %%
# Set starting and end dates
start_date = pd.Timestamp('2014-01-06', tz='utc')
end_date = pd.Timestamp('2016-01-05', tz='utc')

# Run our pipeline for the given start and end dates
output = engine.run_pipeline(pipeline, start_date, end_date)

# Display the pipeline output
output.head()

# %% [markdown]
# ## Solution
#
# [Solution notebook](zipline_coding_exercises_solution.ipynb)
