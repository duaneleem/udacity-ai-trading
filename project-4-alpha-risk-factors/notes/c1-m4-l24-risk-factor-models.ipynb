# %% [markdown]
# # AI for Trading | Module 4 | L22: Factors

# %% [markdown]
# ## 1. Intro
# - https://youtu.be/DgsD3yL9Yy0
#
# ![image.png](attachment:eb6faef3-b4db-425b-96f7-15fb4da03c73.png)

# %% [markdown]
# ## 3. Motivation for Risk Factor Models
# - https://youtu.be/jAQRjxK8PyQ
#   - 1:17 Curse of Dimensionality
#   - 1:37 "Historical Measure" of Risk
#   - Alternative: Risk Factor Model
#
# ### Covariance Matrix of Assets
# We can organize the asset variances and covariances into a matrix.
#
# ![image.png](attachment:813319e9-8930-4f8b-8562-381e65b1fb3e.png)

# %% [markdown]
# ## 5. Factor Model of Asset Return
# - https://youtu.be/7UnllxDmLj8
#
# ### Factor Model of Return
# An asset's return can be modeled as the contribution from a set of factors, plus the specific return (the part that isn't explained by the factors).
#
# ![image.png](attachment:70144c8e-672c-482b-9306-b720e4127881.png)

# %% [markdown]
# ## 7. Factor Model of Portfolio Return
# - https://youtu.be/HEoPljS1wD0
#
# ![image.png](attachment:4b8de45f-018f-43de-a1a3-9c271c5fb15b.png)
#
# ![image.png](attachment:c9f90b3f-13c0-4108-94eb-260ec973e07d.png)

# %% [markdown]
# ## 8. Preview of Portfolio Variance Formula
# - https://youtu.be/llA1A0vjSuI
#
# ![image.png](attachment:6412a6e7-ee85-452f-b1a3-974a6f41fc34.png)

# %% [markdown]
# ## 10. Variance of one stock
# - https://youtu.be/rxaABg4wVZo
#
# ![image.png](attachment:58a73709-3051-495e-affc-695094f9c2a8.png)
#
# ![image.png](attachment:d8dffd7e-0a69-4483-84d8-b027ec6c6d41.png)

# %% [markdown]
# ## 11. Taking constants out of Variance and Covariance (optional)
# - https://youtu.be/M9R9870m_o0
#
# ### Taking a Constant out of the Variance Operator
# ![image.png](attachment:3c1d50d7-d6c2-4613-b5b2-d7614d02d1c0.png)
# ![image.png](attachment:23647804-bc9c-4b8d-805d-006e37f0e565.png)
#
# ### Rewriting the Formula for Asset Variance
# ![image.png](attachment:ee0c3588-61a1-4efc-b812-8c5f118f2eda.png)

# %% [markdown]
# ## 12. Variance of 2 stocks part 1
# - https://youtu.be/PlPusmuR20k
#   - Pairwise Covariance of 2 stocks
#   - ![image.png](attachment:12f2cb4b-a3d0-4951-a41b-bba2d0feff54.png)
#
# ### Covariance of 2 stocks
# The covariance of two stocks can be written as the sum of the covariances of the factors. In this example we have two factors, so we have four covariance terms. If we were using three factors to describe the asset returns, there would be three times three or nine covariance terms.
#
# ![image.png](attachment:1978c644-8e2e-4101-90dd-7bb829b9842f.png)

# %% [markdown]
# ## 13. Variance of 2 stocks part 2
# - https://youtu.be/tSMutw0f6OE
#   -
#
# ### Covariance Matrix of Assets in terms of Factors
# If we write the stock variances and pairwise covariances in terms of the risk factors, we can plug them into the covariance matrix of assets.
#
# ![image.png](attachment:a8d265ea-f809-4e5c-8f34-8542412d00e5.png)
