# %% [markdown]
# # AI for Trading | Module 3 | L20: Portfolio Optimization

# %% [markdown]
# ## 2. What is Optimization
# - https://youtu.be/ISRlP1GeOjU
#
# ### Second-order condition
# In the previous problem, we cheated a little. We knew the shape of the function, and we knew its orientation from our plot, so when we found the point where the derivative equaled 0, we knew we had found the minimum. However, in general, points where the derivative equals 0 could be minima, maxima, or [saddle points](https://en.wikipedia.org/wiki/Saddle_point). To distinguish between these cases, we need to check the function's curvature around the point in question. We do this using the second derivative of the function. For a function of one variable, the rule is:
#
# ![image.png](attachment:651ce536-cfa4-409e-9f34-26d36f12b647.png)
# ![image.png](attachment:5f5d9a5a-e4cb-49e1-9e5a-49ee8d7c30eb.png)

# %% [markdown]
# ## 3. Optimization with Constraints
# -  https://www.youtube.com/watch?v=91WzhG6dti8&t=2s
#   - 0:14 Region of Constraint Satisfaction
#   - 1:20 Optimal or Solution
#     - A vector x that has the smallest objective function value among all vectors that satisfy the constraints.
#     - ![image.png](attachment:4acadbcf-edc7-4df4-bbfd-f129d795c002.png)
#   - 2:40 Convex

# %% [markdown]
# ## 4. Two-Asset Portfolio Optimziation
# ![image.png](attachment:61cea2ff-3fd4-43af-9cfd-52659b259585.png)
# ![image.png](attachment:53dbc8b6-663f-46fd-bff9-4bdd0173b309.png)
# ![image.png](attachment:5eae5ac3-add3-490c-980f-5158926cf20e.png)

# %% [markdown]
# ## 5. Portfolio Optimization with 2 Stocks
# ![image.png](attachment:7acaf219-1fc7-4f35-af80-085197729516.png)
#
# *Note: I will need to revisit this.  It's not clear to me how they took the values and achieved their answers.*

# %% [markdown]
# ## 6. Formulating Portfolio Optimization Problems
# So far, we've discussed one way to formulate a portfolio optimization problem. We learned to set the portfolio variance as the objective function, while imposing the constraint that the portfolio weights should sum to 1. However, in practice you may *frame* the problem a little differently. Let's talk about some of the different ways to set up a portfolio optimization problem.
#
# ### Common Constraints
# ![image.png](attachment:a0c1c52c-e29d-4076-a58f-a49a39969b73.png)
#
# ### Maximizing Portfolio Return
# ![image.png](attachment:40d85414-3ada-40ca-b685-19e4e435cf79.png)
#
# ### A Math Note: the L2-Norm
# ![image.png](attachment:85961157-ba4b-4443-819f-0842708655ca.png)
# ![image.png](attachment:b5736d99-8bea-4990-b803-5d4843483bfc.png)
#
# ### Minimizing Distance to a Set of Target Weights
# ![image.png](attachment:7e2b045f-8ba2-424d-9d07-2475d93c9bc6.png)
#
# ### Tracking an Index
# ![image.png](attachment:e1a80255-320a-48f9-99c8-7dc9dca8c926.png)
#
# ### Quiz Question
# ![image.png](attachment:ba14d4e6-b566-46d7-bb93-8ab3272a598a.png)
#
# Reason: The optimization objective consists of a sum of two quantities: 1) the first term, and 2) the second term times lambda. If lambda is very large, the second quantity in the sum will be larger, and will have more influence on the overall size of the sum. If you choose a larger lambda for the second quantity, the overall optimization will be influenced more by the second quantity.

# %% [markdown]
# ## 7. cvxpy
# ![image.png](attachment:947e0afc-0aa2-45e4-ac5a-08772d489fd0.png)
#
# ### How to use ```cvxpy```
# ![image.png](attachment:11509cea-95b4-4025-9f29-88a76641b28f.png)
# ![image.png](attachment:d13fb587-4d2a-4e57-b574-cb11ab65501e.png)

# %% [markdown]
# ## 10. Rebalancing a Portfolio
# - https://youtu.be/S5SPhBpG3b0

# %% [markdown]
# ## 11. Rebalancing Strategies
# - https://youtu.be/8u5gBx-fYr8

# %% [markdown]
# ## 12. Limitations of the Classical Approach
# - https://youtu.be/UbbZa7-3iuk
