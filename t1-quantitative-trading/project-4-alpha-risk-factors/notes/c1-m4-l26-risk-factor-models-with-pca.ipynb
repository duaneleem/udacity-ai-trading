# %% [markdown]
# # AI for Trading | Module 4 | L25: Time Series and Cross Sectional Risk Models

# %% [markdown]
# ## 2. Vector Two Ways
# - https://youtu.be/mlw6FnCUloU

# %% [markdown]
# ## 3. Refresh Linear Algebra
# - https://www.youtube.com/playlist?list=PLZHQObOWTQDPD3MizzM2xVFitgF8hE_ab

# %% [markdown]
# ## 4. Bases as Languages
# - https://youtu.be/yEL0-AE3mjo
#   - ![image.png](attachment:3d76ef29-db47-4a4e-9174-c52a1f91c721.png)
#   - ![image.png](attachment:13c90e15-ccda-432f-9560-479977508c02.png)

# %% [markdown]
# ## 5. Translating Between Bases
# - https://youtu.be/lrE4VOJ2RCA
#   - ![image.png](attachment:c4e3a602-7cd5-48a4-ae76-fa6df7e29310.png)

# %% [markdown]
# ## 6. The Core Idea
# - https://youtu.be/0KwLkaKHAvg
#   - PCA: Series of calculations that gives us a new and special basis for our data.

# %% [markdown]
# ## 8. Writing it Down: Part 1
# - https://youtu.be/NyDNFqm8c_s

# %% [markdown]
# ## 9. Writing it Down: Part 2
# - https://youtu.be/TSH3hTAHsIg

# %% [markdown]
# ## 10. Writing it Down: Part 3
# - https://youtu.be/kSl0j4QIMIU
#   - 1:50: Rayleigh Quotient
#   - ![image.png](attachment:f2232a8a-6127-4947-871b-90750f398cf3.png)

# %% [markdown]
# ## 11. Writing it Down: Part 4
# - https://youtu.be/7XO-syqIpCE

# %% [markdown]
# ## 12. The Principal Components
# - https://youtu.be/XtecKk58CLs
#   - Basis dimensions

# %% [markdown]
# ## 13. Explained Variance
# - https://youtu.be/OdHeReNUqoQ
#   - 0:15: We don't use all the PCs. Only a fraction of them, starting with 1st.
#   - 1:40: Total variance is independent of basis

# %% [markdown]
# ## 14. PCA Toy Problem
# - https://youtu.be/uyl44T12yU8
#   - See Python notebook associated to this.
#   - 0:00: PCA = Principal Component Analysis

# %% [markdown]
# ## 16. PCA as a Factor Model
# - https://youtu.be/4E3C5E-MmkI
#   - 2:22 ![image.png](attachment:554796e0-9e75-4667-8fe1-7eba2319f7fa.png)
#   - 2:35 ![image.png](attachment:3c9e6e3f-3c77-47c2-8f8e-7e5c871e8de0.png)

# %% [markdown]
# ## 17. PCA as a Factor Model: Part 2
# - https://www.youtube.com/watch?v=lcd-muqX5og
#   - Correction: ![image.png](attachment:bcb20fd2-36bf-4735-994d-67a864b30854.png)
#   - Calculate idiosyncratic (s) ![image.png](attachment:a5136bea-82f2-4412-b9d5-303bc9ae875e.png)
#   - Calculate specific risk matrix: ![image.png](attachment:b3db541e-6a97-4e0e-89d0-e3b05827dfd4.png)
#   - Calculate covariance matrix of the residuals: ![image.png](attachment:1f65510f-6942-4072-a67d-10374e5387e7.png)
