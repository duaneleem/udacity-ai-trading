# %% [markdown]
# # AI for Trading | Week 2 | L14: Volatility

# %% [markdown]
# ## What is Volatility?
# - https://youtu.be/brGVwpDSuG4
#   - 2:20 Voltatility
#     - Measuring risk
#     - Defining position sizes
#     - Designing alpha factors
#     - Pricing options
#     - Trading volatility directly

# %% [markdown]
# ## Historical Voltality
# - TODO: YT Link
#   - 0:13 Calculate the SD of the log returns of some price data
#   - 2:09 Volatility estimate depends on time freuqency of the underlying price data.

# %% [markdown]
# ## Annuualized Volatility
# - TODO: YT Link
#   - 0:05 Extrapolating a SD of log returns calculated at some time frequency to a SD of log returns calculated on an annual frequency.
#
# ### Quiz Question
# What is the typical scale of annualized stock volatility values?
# 0.1 - 0.5

# %% [markdown]
# ## Rolling Windows
# - https://youtu.be/4EuMKqeNXA0
#   - 0:40 To estimate today's volatility, calculate SD of a set of log returns from sometime in the past up to yesterday.

# %% [markdown]
# ## Exponentially Weighted Moving Average
# - https://youtu.be/VBPitTHzYRI
#   - Formula for historical volatility: ![Historical Volatility](../images/c1-2-l14-s8-historical-volatility.png)
#   - Formula for EWMA: ![Exponentially Weighted Moving Average](../images/c1-w2-l14-s8-exponentially-weighted-moving-average.png)

# %% [markdown]
# ## Forecasting Volatility
# - https://youtu.be/82v4v_PKDAE
#   - 0:30 ARCH - Autoregressive Conditionally Heteroscedastic
#   - 1:13 ARCH(1) formula looks like the Exponentially Weighted Moving Average
#   - 2:00 ARCH(m)
#   - 2:24 GARCH(m,n) Generalized ARCH Model

# %% [markdown]
# ## Markets & Volatility
# - https://youtu.be/jEHJkZUX9s4
#   - 0:08 Volatility is caused by new information reaching the market.
#   - 1:19 Volatility and volume are equally correlated.
#   - 2:10 Mean Reversion Strategies
#     - Strategy based on the idea that prices will return to their "running mean" when they go away up or down.
#   - 2:30 Volatility is quoted as the gauge for fear.

# %% [markdown]
# ## Using Volatility for Equity Trading
# - https://youtu.be/Vh9ajVRedvY
#   - Uses of Volatility
#   - 0:28 Mean-reverting Strategy
#   - 1:40 Normalize by volatility
#   - 3:00 Determine position sizes
#   - 3:22 PositionSize formula
#     - ![image.png](attachment:7acd7633-1a23-4dea-90a4-94c91a34ef3a.png)
#   - 4:15 Trading thresholds

# %% [markdown]
# ## Breakout Strategies
# - https://youtu.be/9eamk40DMu0
#   - 0:25 Bollinger Bands
#     - ![image.png](attachment:141364f0-6fea-431a-9f67-aedb0b582f7b.png)
