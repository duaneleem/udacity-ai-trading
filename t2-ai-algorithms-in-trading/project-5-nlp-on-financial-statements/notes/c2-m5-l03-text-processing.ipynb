# %% [markdown]
# # AI for Trading | Module 5 | L01: Welcome

# %% [markdown]
# ## 1. Text Processing
# - https://youtu.be/6LO6I5M18PQ
#   - ![image.png](attachment:b19b1d74-3789-4512-a30f-397e6acfab3c.png)
#
#
# ## 3. Capturing Text Data
# - https://youtu.be/Z4mnMN1ApG4
#
#
# ## 4. Normalization
# - https://youtu.be/eOV2UUY8vtM
#
#
# ## 5. Tokenization
# - https://youtu.be/4Ieotbeh4u8
# - ```nltk.tokenize``` package: https://www.nltk.org/api/nltk.tokenize.html
#
#
# ## 6. Cleaning
# - https://youtu.be/qawXp9DPV6I
#
# ### References
# - Notebook: https://github.com/udacity/AIND-NLP/blob/master/text_processing.ipynb
# - Regular Expressions in Python: https://docs.python.org/3/library/re.html
# - Beautiful Soup: https://www.crummy.com/software/BeautifulSoup/bs4/doc/
#
#
# ## 7. Stop Word Removal
# - https://youtu.be/WAU_Ij0GJbw
#
#
# ## 8. Part-of-Speech Tagging
# - https://youtu.be/WFEu8bXI5OA
#
# ### Note
# Part-of-speech tagging using a predefined grammar like this is a simple, but limited solution. It can be very tedious and error-prone for a large corpus of text, since you have to account for all possible sentence structures and tags!
#
# There are other more advanced forms of POS tagging that can learn sentence structures and tags from given data, including Hidden Markov Models (HMMs) and Recurrent Neural Networks (RNNs).
#
#
# ## 9. Named Entity Recognition
# - https://youtu.be/QUQu2nsE7vE
#
#
# ## 10. Stemming and Lemmatization
# - https://youtu.be/7Gjf81u5hmw
#
#
# ## 11. Exercise: Process Tweets
# - See Notebook: process_tweets
#
#
# ## 13. Summary
# - https://youtu.be/zKYEvRd2XmI
#
# ![image.png](attachment:7d5414eb-6060-461b-9dbe-6611da64a827.png)
