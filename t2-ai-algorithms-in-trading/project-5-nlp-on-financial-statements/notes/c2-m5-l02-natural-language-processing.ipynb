# %% [markdown]
# # AI for Trading | Module 5 | L01: Welcome

# %% [markdown]
# ## 1. NLP Overview
# - https://youtu.be/g-AlFF61p0I
#
#
# ## 2. Structured Languages
# - https://youtu.be/NsmqUIHlk6U
#
#
# ## 3. Grammar
# - https://youtu.be/Jw3dA7xmoQ4
# - Computer Science, Grammar: https://youtu.be/7GmtPqX_YVg
#   - Backus-Naur Form
#
# ### Quiz
# ![image.png](attachment:6dceb608-1bf6-4862-bc9b-957e0b82cb1d.png)
#
#
# ## 4. Unstructured Text
# - https://youtu.be/OmwSdaec5vU
#
# ### Quiz
# ![image.png](attachment:4379fbb1-bf08-490f-bf43-444851081f86.png)
#
#
# ## 6. Context Is Everything
# - https://youtu.be/J-4pfu2w1C0
#
#
# ## 7. NLP and Pipelines
# - https://youtu.be/UQBxJzoCp-I
#
#
# ## 8. How NLP Pipelines Work
# - https://youtu.be/vJx6oKlu_MM
#   - ![image.png](attachment:65b9a085-7a9a-4666-a830-3f825b327547.png)
#
#
# ## 9. Text Processing
# - https://youtu.be/pqheVyctkNQ
#
#
# ## 10. Feature Extraction
# - https://youtu.be/UgENzCmfFWE
#
#
# ## 11. Modeling
# - https://youtu.be/P4w_2rkxBvE
