# %% [markdown]
# # AI for Trading | Module 5 | L05: Financial Statements

# %% [markdown]
# ## 1. Introduction
# - https://youtu.be/BS4n9rRYGtw
#
#
# ## 2. Financial Statements
# - https://youtu.be/XYff0ROHzWo
#   - SEC 10-K, 10-Q
#   - ![image.png](attachment:8daec788-3318-4027-a93c-a1e766d51167.png)
#   - 2:10 EDGAR: Electronic Data Gathering Analysis Retrieval
#
#
# ## 3. 10-K Walkthrough
# - https://youtu.be/0ytyZ4LVG6s
#   - sec.gov
#   - Filings -> EDGAR Search Tools
#
#
# ## 5. Introduction to Regexes
# - https://youtu.be/WCXDD_n1ZuA
#   - Find phone numbers such as 555-111-2222
#     - \d\d\d.\d\d\d.\d\d\d\d
#     - 3 digits, character, 3 digits, character, 4 digits
#
#
# ## 6. Raw Strings
# - https://youtu.be/WhL1VbulThY
# - Need to do the workspace
#
#
# ## 7. Finding Words
# - https://youtu.be/wTOh9B6aHGk
# - Need to do the workspace
