# %% [markdown]
# # AI for Trading | Module 5 | L06: Basic NLP Analysis

# %% [markdown]
# ## 1. Introduction
# - https://youtu.be/94CP-oy5KKI
#
#
# ## 2. Readability
# - https://youtu.be/pcB63lIgiQg
#   - ![image.png](attachment:938a5711-6079-4f6d-9900-2c920a59ff05.png)
#     - 0:47 Long sentences tend to be less readible.
#     - 0:54 Longer words tend to be less readible.
#
#
# ## 4. Bag-of-Words
# - https://youtu.be/8t2bf9kAVHE
#
#
# ## 5. Sentiments from Wordlists
# - https://youtu.be/RutjcGh74Mw
#
# The [Harvard Wordlist](http://www.wjh.harvard.edu/~inquirer/spreadsheet_guide.htm): Created for general document processing. Includes categories such as "pleasure", "vice"...etc
#
# The [Loughran-McDonald Wordlist](https://sraf.nd.edu/textual-analysis/resources/): Created specifically for analyzing financial documents. Contains "positive", "negative", "litigious", "uncertain" categories.
#
#
# ## 6. Frequency Reweighting (TF-IDF)
# - https://youtu.be/X-Cf2Uj7tH4
#   - Term - Frequency - Inverse - Document - Frequency
# - https://youtu.be/OymqCnh-APA
#
#
# ## 7. Similarity Metrics
# - https://youtu.be/LNro_9JOIrY
#   - 2:30 Jaccard Similarity
#   - ![image.png](attachment:f932ea60-6471-44f1-ad80-58b1d3a5ff03.png)
