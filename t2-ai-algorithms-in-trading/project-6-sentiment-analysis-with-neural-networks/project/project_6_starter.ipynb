# %% [markdown]
# # Project 6: Analyzing Stock Sentiment from Twits
# ## Instructions
# Each problem consists of a function to implement and instructions on how to implement the function.  The parts of the function that need to be implemented are marked with a `# TODO` comment.
#
# ## Packages
# When you implement the functions, you'll only need to you use the packages you've used in the classroom, like [Pandas](https://pandas.pydata.org/) and [Numpy](http://www.numpy.org/). These packages will be imported for you. We recommend you don't add any import statements, otherwise the grader might not be able to run your code.
#
# ### Load Packages

# %%
import json
import nltk
import os
import random
import re
import torch

from torch import nn, optim
import torch.nn.functional as F

# %% [markdown]
# ## Introduction
# When deciding the value of a company, it's important to follow the news. For example, a product recall or natural disaster in a company's product chain. You want to be able to turn this information into a signal. Currently, the best tool for the job is a Neural Network.
#
# For this project, you'll use posts from the social media site [StockTwits](https://en.wikipedia.org/wiki/StockTwits). The community on StockTwits is full of investors, traders, and entrepreneurs. Each message posted is called a Twit. This is similar to Twitter's version of a post, called a Tweet. You'll build a model around these twits that generate a sentiment score.
#
# We've collected a bunch of twits, then hand labeled the sentiment of each. To capture the degree of sentiment, we'll use a five-point scale: very negative, negative, neutral, positive, very positive. Each twit is labeled -2 to 2 in steps of 1, from very negative to very positive respectively. You'll build a sentiment analysis model that will learn to assign sentiment to twits on its own, using this labeled data.
#
# The first thing we should to do, is load the data.
#
# ## Import Twits
# ### Load Twits Data
# This JSON file contains a list of objects for each twit in the `'data'` field:
#
# ```
# {'data':
#   {'message_body': 'Neutral twit body text here',
#    'sentiment': 0},
#   {'message_body': 'Happy twit body text here',
#    'sentiment': 1},
#    ...
# }
# ```
#
# The fields represent the following:
#
# * `'message_body'`: The text of the twit.
# * `'sentiment'`: Sentiment score for the twit, ranges from -2 to 2 in steps of 1, with 0 being neutral.
#
#
# To see what the data look like by printing the first 10 twits from the list.

# %%
with open(os.path.join('.', 'data', 'project_6_stocktwits', 'twits.json'), 'r') as f:
    twits = json.load(f)

print(twits['data'][:10])
# Out:
# [{'message_body': '$FITB great buy at 26.00...ill wait', 'sentiment': 2, 'timestamp': '2018-07-01T00:00:09Z'}, {'message_body': '@StockTwits $MSFT', 'sentiment': 1, 'timestamp': '2018-07-01T00:00:42Z'}, {'message_body': '#STAAnalystAlert for $TDG : Jefferies Maintains with a rating of Hold setting target price at USD 350.00. Our own verdict is Buy  http://www.stocktargetadvisor.com/toprating', 'sentiment': 2, 'timestamp': '2018-07-01T00:01:24Z'}, {'message_body': '$AMD I heard there’s a guy who knows someone who thinks somebody knows something - on StockTwits.', 'sentiment': 1, 'timestamp': '2018-07-01T00:01:47Z'}, {'message_body': '$AMD reveal yourself!', 'sentiment': 0, 'timestamp': '2018-07-01T00:02:13Z'}, {'message_body': '$AAPL Why the drop? I warren Buffet taking out his position?', 'sentiment': 1, 'timestamp': '2018-07-01T00:03:10Z'}, {'message_body': '$BA bears have 1 reason on 06-29 to pay more attention https://dividendbot.com?s=BA', 'sentiment': -2, 'timestamp': '2018-07-01T00:04:09Z'}, {'message_body': '$BAC ok good we&#39;re not dropping in price over the weekend, lol', 'sentiment': 1, 'timestamp': '2018-07-01T00:04:17Z'}, {'message_body': '$AMAT - Daily Chart, we need to get back to above 50.', 'sentiment': 2, 'timestamp': '2018-07-01T00:08:01Z'}, {'message_body': '$GME 3% drop per week after spike... if no news in 3 months, back to 12s... if BO, then bingo... what is the odds?', 'sentiment': -2, 'timestamp': '2018-07-01T00:09:03Z'}]

# %% [markdown]
# ### Length of Data
# Now let's look at the number of twits in dataset. Print the number of twits below.

# %%
"""print out the number of twits"""

# TODO Implement 
print(len(twits['data']))
# Out:
# 1548010

# %% [markdown]
# ### Split Message Body and Sentiment Score

# %%
messages = [twit['message_body'] for twit in twits['data']]
# Since the sentiment scores are discrete, we'll scale the sentiments to 0 to 4 for use in our network
sentiments = [twit['sentiment'] + 2 for twit in twits['data']]

# %% [markdown]
# ## Preprocessing the Data
# With our data in hand we need to preprocess our text. These twits are collected by filtering on ticker symbols where these are denoted with a leader $ symbol in the twit itself. For example,
#
# `{'message_body': 'RT @google Our annual look at the year in Google blogging (and beyond) http://t.co/sptHOAh8 $GOOG',
#  'sentiment': 0}`
#
# The ticker symbols don't provide information on the sentiment, and they are in every twit, so we should remove them. This twit also has the `@google` username, again not providing sentiment information, so we should also remove it. We also see a URL `http://t.co/sptHOAh8`. Let's remove these too.
#
# The easiest way to remove specific words or phrases is with regex using the `re` module. You can sub out specific patterns with a space:
#
# ```python
# re.sub(pattern, ' ', text)
# ```
# This will substitute a space with anywhere the pattern matches in the text. Later when we tokenize the text, we'll split appropriately on those spaces.

# %% [markdown]
# ### Pre-Processing

# %%
nltk.download('wordnet')


def preprocess(message):
    """
    This function takes a string as input, then performs these operations: 
        - lowercase
        - remove URLs
        - remove ticker symbols 
        - removes punctuation
        - tokenize by splitting the string on whitespace 
        - removes any single character tokens
    
    Parameters
    ----------
        message : The text message to be preprocessed.
        
    Returns
    -------
        tokens: The preprocessed text into tokens.
    """ 
    #TODO: Implement 
    
    # Lowercase the twit message
    text = message.lower()
    
    # Replace URLs with a space in the message
    text = re.sub(r'https?://[^\s]+', ' ', text)
    
    # Replace ticker symbols with a space. The ticker symbols are any stock symbol that starts with $.
    text = re.sub(r'\$\w+', ' ', text)
    
    # Replace StockTwits usernames with a space. The usernames are any word that starts with @.
    text = re.sub(r'@\w+', ' ', text)

    # Replace everything not a letter with a space
    text = re.sub(r'[^a-zA-Z]', ' ', text)
    
    # Tokenize by splitting the string on whitespace into a list of words
    tokens = text.split(' ')

    # Lemmatize words using the WordNetLemmatizer. You can ignore any word that is not longer than one character.
    wnl = nltk.stem.WordNetLemmatizer()
    tokens = [wnl.lemmatize(w) for w in tokens if len(w) > 1]
    
    assert type(tokens) == list, 'Tokens should be list'
    return tokens
# Out:
# [nltk_data] Downloading package wordnet to /home/jovyan/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# >Note: You must ensure that after preprocessing the text should NOT include:
# - Numbers
# - URLs
# - Single character tokens
# - Ticker symbols (these should be removed even if they don't appear at the beginning)

# %% [markdown]
# ### Preprocess All the Twits
# Now we can preprocess each of the twits in our dataset. Apply the function `preprocess` to all the twit messages.

# %%
# TODO Implement
## Local dev environment required this.
nltk.download('omw-1.4')

tokenized = [preprocess(message) for message in messages]
# Out:
# [nltk_data] Downloading package omw-1.4 to /home/jovyan/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %% [markdown]
# ### Bag of Words
# Now with all of our messages tokenized, we want to create a vocabulary and count up how often each word appears in our entire corpus. Use the [`Counter`](https://docs.python.org/3.1/library/collections.html#collections.Counter) function to count up all the tokens.

# %%
from collections import Counter

"""
Create a vocabulary by using Bag of words
"""

# TODO: Implement 
words = [w for twit in tokenized for w in twit]

bow = Counter(words)

# %%
# List contents of bow for analysis
bow
# Out:
# Counter({'great': 17570,
#          'buy': 76326,
#          'at': 138459,
#          'ill': 883,
#          'wait': 11370,
#          'staanalystalert': 4072,
#          'for': 273545,
#          'jefferies': 1056,
#          'maintains': 903,
#          'with': 68861,
#          'rating': 15436,
#          'of': 211336,
#          'hold': 22152,
#          'setting': 3889,
#          'target': 16580,
#          'price': 37083,
#          'usd': 2955,
#          'our': 12209,
#          'own': 8970,
#          'verdict': 3736,
#          'is': 284887,
#          'heard': 1357,
#          'there': 25944,
#          'guy': 13423,
#          'who': 17884,
#          'know': 19935,
#          'someone': 5192,
#          'think': 24284,
#          'somebody': 1100,
#          'something': 6010,
#          'on': 241666,
#          'stocktwits': 1439,
#          'reveal': 196,
#          'yourself': 1207,
#          'why': 21706,
#          'the': 398810,
#          'drop': 17792,
#          'warren': 1015,
#          'buffet': 1301,
#          'taking': 6418,
#          'out': 56703,
#          'his': 6256,
#          'position': 11753,
#          'bear': 33541,
#          'have': 52965,
#          'reason': 7777,
#          'to': 379508,
#          'pay': 7609,
#          'more': 55368,
#          'attention': 3531,
#          'ok': 4567,
#          'good': 44206,
#          'we': 64757,
#          're': 13190,
#          'not': 68308,
#          'dropping': 2269,
#          'in': 205323,
#          'over': 32685,
#          'weekend': 3561,
#          'lol': 30941,
#          'daily': 14035,
#          'chart': 15996,
#          'need': 21657,
#          'get': 46704,
#          'back': 43061,
#          'above': 17856,
#          'per': 16565,
#          'week': 44055,
#          'after': 34396,
#          'spike': 2204,
#          'if': 59001,
#          'no': 40432,
#          'news': 19727,
#          'month': 16913,
#          'bo': 610,
#          'then': 20974,
#          'bingo': 181,
#          'what': 79141,
#          'odds': 392,
#          'strong': 17202,
#          'short': 86671,
#          'ratio': 7664,
#          'and': 208508,
#          'float': 4654,
#          'via': 23490,
#          'squeezing': 228,
#          'perfect': 1988,
#          'place': 2849,
#          'an': 22501,
#          'option': 20515,
#          'straddle': 2232,
#          'near': 5825,
#          'supporting': 276,
#          'trend': 8087,
#          'start': 8861,
#          'new': 46415,
#          'monday': 7383,
#          'expect': 10359,
#          'volume': 43709,
#          'across': 781,
#          'key': 8464,
#          'company': 22151,
#          'various': 84,
#          'sector': 5047,
#          'breakout': 6677,
#          'strategy': 1608,
#          'current': 6187,
#          'portfolio': 2469,
#          'bull': 27167,
#          'catalyst': 1284,
#          'continuing': 351,
#          'this': 203572,
#          'uptrend': 1688,
#          'pill': 196,
#          'pack': 191,
#          'amazon': 10934,
#          'prime': 1825,
#          'day': 67487,
#          'earnings': 52932,
#          'test': 4027,
#          'break': 17101,
#          'soon': 16160,
#          'ha': 44265,
#          'moved': 3368,
#          'check': 5455,
#          'movement': 2866,
#          'peer': 3180,
#          'mkm': 164,
#          'partner': 1166,
#          'set': 5841,
#          'it': 193536,
#          'too': 18991,
#          'early': 4770,
#          'tell': 4651,
#          'going': 48017,
#          'happen': 4281,
#          'even': 15815,
#          'about': 27608,
#          'raisinf': 1,
#          'output': 109,
#          'still': 35231,
#          'so': 45889,
#          'many': 9461,
#          'financially': 570,
#          'healthy': 1808,
#          'problem': 2754,
#          'meeting': 1002,
#          'obligation': 670,
#          'bullish': 25205,
#          'stock': 75433,
#          'watch': 14696,
#          'setup': 8108,
#          'timeframes': 39,
#          'blog': 539,
#          'by': 53983,
#          'just': 73196,
#          'high': 28326,
#          'alert': 12213,
#          'next': 46982,
#          'gt': 9390,
#          'breakdown': 1104,
#          'much': 16601,
#          'better': 13772,
#          'than': 29130,
#          'industry': 7782,
#          'average': 9331,
#          'miss': 6974,
#          'these': 14131,
#          'confirms': 411,
#          'you': 94325,
#          'will': 128206,
#          'see': 44343,
#          'violent': 147,
#          'move': 22530,
#          'downward': 831,
#          'my': 51356,
#          'base': 1468,
#          'gap': 9764,
#          'ma': 5054,
#          'cabot': 106,
#          'weekly': 7172,
#          'video': 2816,
#          'quot': 40091,
#          'resilient': 137,
#          'growth': 36093,
#          'when': 30042,
#          'wa': 55257,
#          'kid': 1696,
#          'froend': 1,
#          'told': 3842,
#          'me': 25902,
#          'moon': 2177,
#          'made': 7819,
#          'cheese': 116,
#          'percent': 6303,
#          'rank': 5337,
#          'th': 6559,
#          'percentile': 1399,
#          'thank': 4123,
#          'don': 25444,
#          'feel': 5989,
#          'or': 37469,
#          'do': 24610,
#          'well': 16550,
#          'they': 56357,
#          'already': 9658,
#          'during': 2561,
#          'youtube': 598,
#          'interview': 623,
#          'mitch': 62,
#          'couldn': 1252,
#          'remember': 4819,
#          'single': 2166,
#          'movie': 881,
#          'he': 11568,
#          'watched': 394,
#          'all': 59896,
#          'year': 34383,
#          'except': 1131,
#          'star': 2384,
#          'war': 4958,
#          'black': 1214,
#          'panther': 25,
#          'clothes': 115,
#          'downgrade': 4255,
#          'sale': 27059,
#          'interest': 11781,
#          'return': 7074,
#          'equity': 3267,
#          'although': 1869,
#          'market': 53671,
#          'up': 121577,
#          'doing': 5537,
#          'advanced': 992,
#          'a': 46191,
#          'info': 3817,
#          'july': 3147,
#          'be': 89281,
#          'most': 8235,
#          'normal': 1624,
#          'friday': 11161,
#          'contract': 14254,
#          'call': 67762,
#          'put': 36950,
#          'third': 1593,
#          'design': 609,
#          'win': 5867,
#          'timing': 658,
#          'match': 409,
#          'probably': 5059,
#          'arm': 307,
#          'alcohol': 72,
#          'tobacco': 149,
#          'firearm': 3,
#          'president': 2847,
#          'trump': 11800,
#          'tweet': 1397,
#          'spoke': 172,
#          'king': 1307,
#          'salman': 4,
#          'saudi': 757,
#          'arabia': 150,
#          'explained': 115,
#          'him': 2091,
#          'that': 89677,
#          'because': 7871,
#          'turmoil': 129,
#          'amp': 35686,
#          'today': 76248,
#          'insight': 8187,
#          'intc': 1984,
#          'mama': 154,
#          'said': 9402,
#          'ice': 375,
#          'cream': 115,
#          'finish': 1167,
#          'due': 3700,
#          'dil': 3,
#          'noticed': 365,
#          'last': 38611,
#          'jedi': 176,
#          'stream': 605,
#          'love': 10349,
#          'here': 74957,
#          'go': 52761,
#          'leave': 1353,
#          'view': 5128,
#          'look': 31200,
#          'ema': 1388,
#          'held': 2811,
#          'stochastics': 73,
#          'turning': 1167,
#          'spy': 2137,
#          'qqq': 655,
#          'opposite': 876,
#          'forward': 3415,
#          'pe': 4546,
#          'valuation': 4518,
#          'can': 44221,
#          'described': 346,
#          'cheap': 7837,
#          'saber': 13,
#          'capital': 2886,
#          'presentation': 626,
#          'common': 1432,
#          'denominator': 9,
#          'tencent': 164,
#          'facebook': 8707,
#          'google': 3214,
#          'how': 24453,
#          'one': 27505,
#          'performing': 859,
#          'crude': 489,
#          'petroleum': 249,
#          'natural': 517,
#          'gas': 1494,
#          'pu': 49,
#          'simply': 636,
#          'havent': 214,
#          'lost': 4552,
#          'any': 14394,
#          'brown': 254,
#          'run': 15786,
#          'tech': 9891,
#          'mf': 308,
#          'are': 101427,
#          'educated': 114,
#          'their': 24227,
#          'shit': 6413,
#          'every': 8941,
#          'former': 435,
#          'global': 2508,
#          'manufacturing': 363,
#          'pfizer': 452,
#          'independent': 150,
#          'director': 5452,
#          'nat': 136,
#          'ricciardi': 4,
#          'may': 10952,
#          'safest': 153,
#          'special': 627,
#          'limited': 553,
#          'offer': 1526,
#          'june': 1300,
#          'tradenet': 4,
#          'offering': 643,
#          'discount': 1455,
#          'intro': 49,
#          'program': 1011,
#          'below': 11232,
#          'financials': 989,
#          'summary': 464,
#          'jeff': 687,
#          'gundlach': 41,
#          'sohn': 23,
#          'long': 32557,
#          'thesis': 1005,
#          'energy': 2789,
#          'low': 23159,
#          'peg': 547,
#          'which': 8193,
#          'compensates': 296,
#          'indicates': 1981,
#          'rather': 2368,
#          'pres': 352,
#          'coming': 18932,
#          'seems': 5392,
#          'support': 16991,
#          'under': 8997,
#          'likely': 3646,
#          'bullshit': 875,
#          'worthless': 1025,
#          'mean': 6164,
#          'fucking': 2385,
#          'nothing': 7014,
#          'macau': 279,
#          'usa': 1071,
#          'take': 17635,
#          'let': 26918,
#          'where': 12422,
#          'right': 19051,
#          'now': 57534,
#          'ugly': 1841,
#          'without': 2339,
#          'clear': 2622,
#          'level': 9589,
#          'term': 17568,
#          'bearish': 11440,
#          'll': 13146,
#          'previously': 2035,
#          'mo': 893,
#          'followed': 973,
#          'end': 15778,
#          'another': 14004,
#          'runup': 188,
#          'dropped': 2955,
#          'smart': 3332,
#          'money': 24860,
#          'betting': 856,
#          'deal': 6722,
#          'update': 20555,
#          'technical': 11303,
#          'bad': 13240,
#          'doe': 11174,
#          'present': 2424,
#          'nice': 17344,
#          'opportunity': 5874,
#          'completely': 1017,
#          'scale': 382,
#          'time': 39415,
#          'gobble': 106,
#          'play': 9231,
#          'aka': 336,
#          'favorite': 870,
#          'them': 11059,
#          'iddy': 1,
#          'bitty': 10,
#          'kiddy': 33,
#          'hand': 3733,
#          'awesome': 1846,
#          'concerned': 541,
#          'eow': 2109,
#          'might': 8907,
#          'wk': 1305,
#          'throwback': 59,
#          'u': 13294,
#          'advisor': 220,
#          'upgrade': 6839,
#          'shorties': 808,
#          'dreaming': 232,
#          'depression': 139,
#          'somethin': 27,
#          'loll': 48,
#          'updated': 814,
#          'hormel': 115,
#          'food': 1482,
#          'dividend': 8422,
#          'analysis': 3390,
#          'consumer': 1989,
#          'defensive': 282,
#          'intel': 7968,
#          'profitability': 1887,
#          'safety': 1126,
#          'score': 2652,
#          'technology': 3125,
#          'both': 6238,
#          'positive': 9034,
#          'looking': 17934,
#          'mad': 1240,
#          'report': 55267,
#          'block': 9925,
#          'person': 698,
#          'spam': 272,
#          'should': 24027,
#          'open': 20695,
#          'projection': 280,
#          'thats': 2258,
#          'true': 2132,
#          'prefer': 361,
#          'from': 62387,
#          'turd': 1080,
#          'wal': 125,
#          'mart': 147,
#          'aristocrat': 302,
#          'valueinvesting': 53,
#          'dvb': 22,
#          'aaamp': 28,
#          'marriage': 38,
#          'bank': 7542,
#          'account': 2801,
#          'dm': 57,
#          'won': 5420,
#          'stop': 12796,
#          'posting': 1290,
#          'holding': 14809,
#          'big': 27628,
#          'calm': 907,
#          'down': 69368,
#          'luck': 3427,
#          'chase': 1362,
#          'continues': 2442,
#          'hopefully': 2618,
#          'catch': 1750,
#          'before': 25834,
#          'lisa': 3075,
#          'announces': 3374,
#          'rd': 1374,
#          'permamently': 1,
#          'turned': 1356,
#          'off': 21258,
#          'trading': 21177,
#          'maybe': 7823,
#          'altogether': 26,
#          'manipulation': 2484,
#          'very': 20008,
#          'rich': 1601,
#          'make': 19934,
#          'poor': 1889,
#          'fuk': 226,
#          'almost': 5592,
#          'pct': 747,
#          'buyback': 5102,
#          'got': 16215,
#          'share': 48702,
#          'though': 4117,
#          'drip': 324,
#          'dumped': 1063,
#          'obv': 181,
#          'but': 53512,
#          'jeez': 339,
#          'bit': 4450,
#          'done': 5480,
#          'bounce': 11618,
#          'heikin': 10,
#          'ashi': 12,
#          'candle': 3264,
#          'confirmation': 739,
#          'liking': 419,
#          'wife': 650,
#          'tree': 514,
#          'fiddy': 32,
#          'sure': 8301,
#          'piggy': 270,
#          'lot': 10025,
#          'coin': 405,
#          'spend': 805,
#          'candy': 113,
#          'microsoft': 1969,
#          'investor': 8403,
#          'aren': 1687,
#          'happy': 4356,
#          'royal': 433,
#          'canada': 1345,
#          'reiterates': 1333,
#          'outperform': 1850,
#          'loop': 286,
#          'raise': 5772,
#          'never': 9018,
#          'been': 19825,
#          'wrong': 5608,
#          'miracle': 311,
#          'period': 1162,
#          'bollinger': 1347,
#          'band': 1516,
#          'dare': 353,
#          'say': 16287,
#          'didn': 5922,
#          'guilty': 97,
#          'fudge': 65,
#          'hardly': 255,
#          'ever': 5632,
#          'informative': 33,
#          'comment': 2098,
#          'page': 564,
#          'broken': 1592,
#          'giving': 1778,
#          'endless': 233,
#          'buffering': 4,
#          'icon': 95,
#          'give': 7675,
#          'viral': 18,
#          'walk': 1117,
#          'away': 4801,
#          'highlight': 249,
#          'growing': 2233,
#          'democrat': 278,
#          'leaving': 872,
#          'party': 1707,
#          'epoch': 2,
#          'robert': 973,
#          'baird': 650,
#          'neutral': 3513,
#          'weed': 717,
#          'other': 8473,
#          'drug': 1313,
#          'guess': 5927,
#          'reasonable': 610,
#          'nike': 4005,
#          'winning': 2108,
#          'click': 886,
#          'booking': 824,
#          'app': 5948,
#          'native': 20,
#          'seamless': 10,
#          'lovalized': 1,
#          'transactable': 1,
#          'ap': 80,
#          'vitiello': 1,
#          'tapped': 126,
#          'acting': 770,
#          'reach': 1962,
#          'iconic': 63,
#          'brand': 1969,
#          'built': 445,
#          'mobile': 965,
#          'show': 9569,
#          'morning': 11342,
#          'heading': 2783,
#          'ath': 3145,
#          'acquisition': 1769,
#          'total': 6061,
#          'past': 8306,
#          'exit': 1473,
#          'zone': 1588,
#          'fantastic': 574,
#          'read': 3822,
#          'oil': 4760,
#          'tighten': 205,
#          'bbl': 150,
#          'getting': 12183,
#          'closer': 977,
#          'greatest': 421,
#          'yearly': 1241,
#          'performance': 2094,
#          'did': 12610,
#          'champion': 159,
#          'cashflow': 75,
#          'highyield': 23,
#          'telecommunication': 7,
#          'pretty': 4504,
#          'risky': 713,
#          'gamble': 832,
#          'either': 3236,
#          'plummet': 326,
#          'rally': 6210,
#          'stronger': 867,
#          'apple': 12830,
#          'talking': 2745,
#          'referring': 107,
#          'intelsat': 6,
#          'punish': 128,
#          'seller': 3017,
#          'warehouse': 88,
#          'sense': 2205,
#          'old': 3815,
#          'gather': 129,
#          'dust': 433,
#          'pc': 615,
#          'gamers': 213,
#          'crypto': 1741,
#          'miner': 169,
#          'gpu': 1306,
#          'enthusiast': 27,
#          'waiting': 7246,
#          'two': 5514,
#          'only': 19012,
#          'medium': 3271,
#          'decent': 2928,
#          'pattern': 6528,
#          'five': 740,
#          'baba': 546,
#          'ahhhhhhhhhhhhhhhhhhhhh': 1,
#          'raytheon': 176,
#          'industrials': 309,
#          'military': 308,
#          'trending': 1957,
#          'riiiiiiiiiich': 1,
#          'sooooon': 11,
#          'buuuuls': 1,
#          'looooove': 4,
#          'drunk': 207,
#          'doesn': 6277,
#          'through': 6157,
#          'gapping': 285,
#          'warbey': 1,
#          'parker': 204,
#          'prep': 102,
#          'glass': 296,
#          'seen': 3833,
#          'focus': 1057,
#          'fashion': 212,
#          'wrt': 16,
#          'wearable': 106,
#          'like': 51921,
#          'sbux': 227,
#          'paying': 1526,
#          'full': 2984,
#          'sex': 171,
#          'change': 5184,
#          'employee': 1101,
#          'hit': 12524,
#          'bottom': 9698,
#          'line': 7061,
#          'recap': 1344,
#          'since': 22612,
#          'post': 7910,
#          'trade': 49477,
#          'included': 375,
#          'hsy': 25,
#          'uri': 46,
#          'sonc': 11,
#          'dri': 41,
#          'kmx': 32,
#          'wynn': 506,
#          'akam': 48,
#          'enterprise': 1330,
#          'value': 5684,
#          'v': 5392,
#          'cap': 4044,
#          'difference': 602,
#          'actual': 649,
#          'asset': 1897,
#          'spread': 2455,
#          'way': 16482,
#          'undervalued': 2519,
#          'million': 6353,
#          'added': 5564,
#          'dont': 6263,
#          'become': 1583,
#          'such': 2917,
#          'monopoly': 326,
#          'dipping': 306,
#          'into': 17280,
#          'everything': 4297,
#          'airline': 944,
#          'possibility': 469,
#          'loss': 7745,
#          'suggested': 321,
#          'chartmill': 199,
#          'analyzer': 520,
#          'resistance': 7073,
#          'len': 58,
#          'reversal': 4918,
#          'progress': 565,
#          've': 6742,
#          'recently': 828,
#          'closed': 3355,
#          'list': 3255,
#          'bought': 19135,
#          'same': 12092,
#          'used': 1744,
#          'according': 2034,
#          'data': 9734,
#          'reported': 14152,
#          'finra': 2763,
#          'clocked': 707,
#          'official': 472,
#          'came': 1631,
#          'saying': 4024,
#          'agree': 1544,
#          'resume': 516,
#          'cover': 5879,
#          'penis': 47,
#          'putang': 1,
#          'front': 570,
#          'leg': 2239,
#          'would': 22411,
#          'some': 30472,
#          'am': 14383,
#          'watching': 5571,
#          'wonder': 2999,
#          'valued': 1624,
#          'inning': 69,
#          'higher': 25481,
#          'also': 7917,
#          'shorted': 2973,
#          'consolidation': 2030,
#          'cautious': 516,
#          'stunned': 42,
#          'deeply': 92,
#          'disappointed': 457,
#          'close': 29517,
#          'ending': 1214,
#          'killed': 1221,
#          'best': 9982,
#          'february': 375,
#          'funny': 2522,
#          'thing': 12606,
#          'similar': 1136,
#          'story': 2651,
#          'different': 1559,
#          'crab': 39,
#          'measured': 489,
#          'divergence': 774,
#          'really': 11288,
#          'momentum': 3392,
#          'starting': 3250,
#          'shi': 59,
#          'venture': 299,
#          'tariff': 8068,
#          'increase': 3983,
#          'profit': 16092,
#          'recession': 1042,
#          'come': 18482,
#          'keep': 14977,
#          'buying': 23827,
#          'pure': 933,
#          'beanscreen': 2,
#          'min': 5729,
#          'indicating': 431,
#          'accumulation': 732,
#          'eod': 5174,
#          'could': 16217,
#          'pop': 7581,
#          'heavy': 1715,
#          'apog': 7,
#          'acn': 46,
#          'camp': 62,
#          'gi': 61,
#          'payx': 23,
#          'fdx': 113,
#          'goo': 179,
#          'squeeze': 5672,
#          'pullback': 4543,
#          'upside': 5176,
#          'nvda': 3196,
#          'safe': 1991,
#          'yield': 2523,
#          'div': 2205,
#          'adding': 2957,
#          'gladly': 91,
#          'irrationality': 24,
#          'reign': 40,
#          'possible': 4173,
#          'excess': 66,
#          'gain': 11675,
#          'welcome': 1341,
#          'gl': 3047,
#          'seeing': 2562,
#          'jumping': 707,
#          'joy': 272,
#          'least': 5507,
#          'given': 2986,
#          'action': 6832,
#          'bouncing': 948,
#          'continuation': 584,
#          'hopeful': 168,
#          'science': 320,
#          'officially': 540,
#          'became': 318,
#          'major': 3733,
#          'university': 70,
#          'ai': 1731,
#          'brainers': 5,
#          'era': 292,
#          'second': 3447,
#          'minute': 5133,
#          'rule': 2004,
#          'applies': 83,
#          'zbra': 6,
#          'six': 557,
#          'fc': 23,
#          'gbx': 4,
#          'fds': 31,
#          'avav': 9,
#          'killing': 1666,
#          'tax': 2252,
#          'cut': 4888,
#          'idea': 3827,
#          'haven': 1829,
#          'posted': 4218,
#          'while': 7227,
#          'omg': 1698,
#          'toy': 360,
#          'land': 607,
#          'amazing': 3002,
#          'contributed': 38,
#          'ytd': 1173,
#          'popular': 406,
#          'word': 2041,
#          'buyin': 130,
#          'those': 9851,
#          'dip': 17730,
#          'haha': 2082,
#          'makin': 55,
#          'rain': 217,
#          'white': 924,
#          'house': 1699,
#          'quality': 1462,
#          'moment': 2631,
#          'doubt': 1738,
#          'production': 937,
#          'eps': 33292,
#          'constellation': 327,
#          'disney': 1297,
#          'clinch': 9,
#          'acquire': 712,
#          'fox': 767,
#          'group': 4422,
#          'counter': 250,
#          'aggregate': 761,
#          'southwest': 152,
#          'flight': 328,
#          'dallas': 44,
#          'delta': 421,
#          'spat': 52,
#          'california': 290,
#          'netflix': 5120,
#          'inc': 7010,
#          'nflx': 3251,
#          'versus': 926,
#          'fb': 7815,
#          'starbucks': 593,
#          'using': 2148,
#          'iex': 2187,
#          'calculate': 207,
#          'shorters': 271,
#          'emergence': 1,
#          'bankruptcy': 1423,
#          'emergency': 85,
#          'zwj': 6,
#          'investment': 4288,
#          'counsel': 371,
#          'lower': 16060,
#          'stake': 1025,
#          'unitedhealth': 172,
#          'unh': 107,
#          'tyzen': 1,
#          'vega': 682,
#          'laptop': 368,
#          'investing': 1676,
#          'annuity': 17,
#          'yr': 2894,
#          'bond': 1263,
#          'continue': 3691,
#          'add': 6076,
#          'unsure': 70,
#          'country': 1033,
#          'amd': 22534,
#          'ryzen': 1003,
#          'gettin': 151,
#          'blasted': 70,
#          'cgnx': 6,
#          'cx': 28,
#          'aaoi': 53,
#          'aa': 75,
#          'amswa': 1,
#          'yy': 20,
#          'snx': 8,
#          'shark': 214,
#          'definitely': 1899,
#          'august': 2665,
#          'g': 1228,
#          'point': 8711,
#          'huge': 9307,
#          'closing': 3857,
#          'scalp': 1291,
#          'giant': 1404,
#          'fermenting': 1,
#          'marked': 88,
#          'compared': 2780,
#          'book': 1963,
#          'cheaply': 737,
#          'quite': 3393,
#          'job': 3568,
#          'started': 5092,
#          'clearly': 1056,
#          'cup': 1974,
#          'holder': 2398,
#          'inverse': 505,
#          'confidence': 771,
#          'debt': 3076,
#          'sell': 35150,
#          'interesting': 3532,
#          'frame': 436,
#          'trader': 4621,
#          'meanwhile': 505,
#          'galaxy': 121,
#          'far': 5527,
#          'broadening': 29,
#          'wedge': 1253,
#          'descending': 312,
#          'large': 6258,
#          'im': 5083,
#          'pt': 16021,
#          'three': 1642,
#          'falling': 3279,
#          'peak': 1897,
#          'fourth': 250,
#          'everyone': 8409,
#          'coke': 281,
#          'smile': 213,
#          'thanks': 5687,
#          'selling': 17609,
#          'prove': 454,
#          'terrible': 937,
#          'error': 161,
#          'article': 2513,
#          'hint': 345,
#          'sogou': 11,
#          'finger': 680,
#          'crossed': 1344,
#          'triple': 1168,
#          'top': 14099,
#          'bro': 615,
#          'work': 5147,
#          'delete': 293,
#          'blue': 1663,
#          'arrow': 118,
#          'your': 25510,
#          'delusion': 82,
#          'overbought': 1692,
#          'changing': 490,
#          'mr': 1179,
#          'yo': 895,
#          'hi': 794,
#          'bed': 715,
#          'night': 2769,
#          'prepared': 346,
#          'policy': 364,
#          ...})

# %% [markdown]
# ### Frequency of Words Appearing in Message
# With our vocabulary, now we'll remove some of the most common words such as 'the', 'and', 'it', etc. These words don't contribute to identifying sentiment and are really common, resulting in a lot of noise in our input. If we can filter these out, then our network should have an easier time learning.
#
# We also want to remove really rare words that show up in a only a few twits. Here you'll want to divide the count of each word by the **number of messages** calculated in the code block above (i.e. `len(messages))`. Then remove words that only appear in some small fraction of the messages.
#
# >Note: There is not an exact number for low and high-frequency cut-offs, however there is a correct optimal range.
# You should ideally set up low-frequency cut-off from 0.0000002 to 0.000007 (inclusive) and high-frequency from 5 to 20 (inclusive). If the number is too big, we lose lots of important words that we can use in our data.

# %%
"""
Set the following variables:
    freqs
    low_cutoff
    high_cutoff
    K_most_common
"""

# TODO Implement 

# Dictionart that contains the Frequency of words appearing in messages.
# The key is the token and the value is the frequency of that word in the corpus.
freqs = dict(bow)

# Float that is the frequency cutoff. Drop words with a frequency that is lower or equal to this number.
low_cutoff = 0.0000003

# Integer that is the cut off for most common words. Drop words that are the `high_cutoff` most common words.
high_cutoff = 15

# The k most common words in the corpus. Use `high_cutoff` as the k.
K_most_common = [word[0] for word in bow.most_common(high_cutoff)]


filtered_words = [word for word in freqs if (freqs[word] > low_cutoff and word not in K_most_common)]
print(K_most_common)
len(filtered_words)
# Out:
# ['the', 'to', 'is', 'for', 'on', 'of', 'and', 'in', 'this', 'it', 'at', 'will', 'up', 'are', 'you']
# 98410

# %% [markdown]
# ### Updating Vocabulary by Removing Filtered Words
# Let's creat three variables that will help with our vocabulary.

# %%
"""
Set the following variables:
    vocab
    id2vocab
    filtered
"""

#TODO Implement

# A dictionary for the `filtered_words`. The key is the word and value is an id that represents the word. 
vocab = { word:idx+1 for idx, word in enumerate(filtered_words) }

# Reverse of the `vocab` dictionary. The key is word id and value is the word. 
id2vocab = { idx:word for word, idx in vocab.items() }

# tokenized with the words not in `filtered_words` removed.
filtered = [[token for token in message if token in vocab] for message in tokenized]


assert set(vocab.keys()) == set(id2vocab.values()), 'Check vocab and id2vocab dictionaries'

# %%
# Analyze filtered
print(len(filtered))
filtered[:3]
# Out:
# 1548010
# [['great', 'buy', 'ill', 'wait'],
#  [],
#  ['staanalystalert',
#   'jefferies',
#   'maintains',
#   'with',
#   'rating',
#   'hold',
#   'setting',
#   'target',
#   'price',
#   'usd',
#   'our',
#   'own',
#   'verdict',
#   'buy']]

# %% [markdown]
# ### Balancing the classes
# Let's do a few last pre-processing steps. If we look at how our twits are labeled, we'll find that 50% of them are neutral. This means that our network will be 50% accurate just by guessing 0 every single time. To help our network learn appropriately, we'll want to balance our classes.
# That is, make sure each of our different sentiment scores show up roughly as frequently in the data.
#
# What we can do here is go through each of our examples and randomly drop twits with neutral sentiment. What should be the probability we drop these twits if we want to get around 20% neutral twits starting at 50% neutral? We should also take this opportunity to remove messages with length 0.

# %%
balanced = {'messages': [], 'sentiments':[]}

n_neutral = sum(1 for each in sentiments if each == 2)
N_examples = len(sentiments)
keep_prob = (N_examples - n_neutral)/4/n_neutral

for idx, sentiment in enumerate(sentiments):
    message = filtered[idx]
    if len(message) == 0:
        # skip this message because it has length zero
        continue
    elif sentiment != 2 or random.random() < keep_prob:
        balanced['messages'].append(message)
        balanced['sentiments'].append(sentiment)

# %% [markdown]
# If you did it correctly, you should see the following result

# %%
n_neutral = sum(1 for each in balanced['sentiments'] if each == 2)
N_examples = len(balanced['sentiments'])
n_neutral/N_examples
# Out:
# 0.19535693805117713

# %% [markdown]
# Finally let's convert our tokens into integer ids which we can pass to the network.

# %%
token_ids = [[vocab[word] for word in message] for message in balanced['messages']]
sentiments = balanced['sentiments']

# %% [markdown]
# ## Neural Network
# Now we have our vocabulary which means we can transform our tokens into ids, which are then passed to our network. So, let's define the network now!
#
# Here is a nice diagram showing the network we'd like to build:
#
# #### Embed -> RNN -> Dense -> Softmax
# ### Implement the text classifier
# Before we build text classifier, if you remember from the other network that you built in  "Sentiment Analysis with an RNN"  exercise  - which there, the network called " SentimentRNN", here we named it "TextClassifer" - consists of three main parts: 1) init function `__init__` 2) forward pass `forward`  3) hidden state `init_hidden`.
#
# This network is pretty similar to the network you built expect in the  `forward` pass, we use softmax instead of sigmoid. The reason we are not using sigmoid is that the output of NN is not a binary. In our network, sentiment scores have 5 possible outcomes. We are looking for an outcome with the highest probability thus softmax is a better choice.

# %%
# First checking if GPU is available
train_on_gpu=torch.cuda.is_available()

if(train_on_gpu):
    print('Training on GPU.')
else:
    print('No GPU available, training on CPU.')
# Out:
# No GPU available, training on CPU.

# %%
class TextClassifier(nn.Module):
    def __init__(self, vocab_size, embed_size, lstm_size, output_size, lstm_layers=1, dropout=0.1):
        """
        Initialize the model by setting up the layers.
        
        Parameters
        ----------
            vocab_size : The vocabulary size.
            embed_size : The embedding layer size.
            lstm_size : The LSTM layer size.
            output_size : The output size.
            lstm_layers : The number of LSTM layers.
            dropout : The dropout probability.
        """
        
        super().__init__()
        self.vocab_size = vocab_size
        self.embed_size = embed_size
        self.lstm_size = lstm_size
        self.output_size = output_size
        self.lstm_layers = lstm_layers
        self.dropout = dropout
        
        # TODO Implement

        # Setup embedding layer
        self.embedding = nn.Embedding(vocab_size, embed_size)
        
        # Setup additional layers
        self.lstm = nn.LSTM(
            input_size = self.embed_size, 
            hidden_size = self.lstm_size, 
            num_layers = self.lstm_layers,
            dropout = self.dropout, 
            batch_first = False
        )
        
        # Dropout Layer
        self.dropout = nn.Dropout(p = dropout)
        
        # Linear and SoftMax Layer
        self.fc = nn.Linear(self.lstm_size, self.output_size)
        self.logsoftmax = nn.LogSoftmax(dim = 1)


    def init_hidden(self, batch_size):
        """ 
        Initializes hidden state
        
        Parameters
        ----------
            batch_size : The size of batches.
        
        Returns
        -------
            hidden_state
            
        """
        
        # TODO Implement 
        
        # Create two new tensors with sizes n_layers x batch_size x hidden_dim,
        # initialized to zero, for hidden state and cell state of LSTM
        weight_param = next(self.parameters())
        weight = weight_param.data
        current_device = weight_param.device
        
        if (train_on_gpu and str(current_device) == 'cuda'):
            hidden = (
                weight.new(self.lstm_layers, batch_size, self.lstm_size).zero_().cuda(),
                weight.new(self.lstm_layers, batch_size, self.lstm_size).zero_().cuda()
            )
        else:
            hidden = (
                weight.new(self.lstm_layers, batch_size, self.lstm_size).zero_(),
                weight.new(self.lstm_layers, batch_size, self.lstm_size).zero_()
            )
        
        return hidden


    def forward(self, nn_input, hidden_state):
        """
        Perform a forward pass of our model on nn_input.
        
        Parameters
        ----------
            nn_input : The batch of input to the NN.
            hidden_state : The LSTM hidden state.

        Returns
        -------
            logps: log softmax output
            hidden_state: The new hidden state.

        """
        
        # TODO Implement 
        
        # embeddings and lstm_out
        embeds = self.embedding(nn_input)
        lstm_out, hidden_state = self.lstm(embeds, hidden_state)
        
        # get the last time step output
        #lstm_out = lstm_out.contiguous().view(-1, self.lstm_size)
        lstm_out = lstm_out[-1]
        
        # dropout and fully-connected layer
        #out = self.dropout(lstm_out)
        #out = self.fc(out)
        
        # sigmoid function
        #sig_out = self.sig(out)
        # SoftMax output
        #logps = self.logsoftmax(out)
        logps = self.logsoftmax(self.dropout(self.fc(lstm_out)))
        
        # reshape to be batch size first
        #sig_out = sig_out.view(batch_size, -1)
        #logps = logps.view(-1, batch_size, self.output_size)
        #sig_out = sig_out[:, -1]
        #logps = logps[-1,:,:]
        
        # return softmax output and hidden state
        return logps, hidden_state

# %% [markdown]
# ### View Model

# %%
model = TextClassifier(len(vocab), 10, 6, 5, dropout=0.1, lstm_layers=2)
model.embedding.weight.data.uniform_(-1, 1)
input = torch.randint(0, 1000, (5, 4), dtype=torch.int64)
hidden = model.init_hidden(4)

logps, _ = model.forward(input, hidden)
print(logps)
# Out:
# tensor([[-1.5720, -1.3747, -1.9123, -1.4134, -1.9078],
#         [-1.6478, -1.4116, -1.9406, -1.4392, -1.6980],
#         [-1.6323, -1.4208, -1.9514, -1.4391, -1.6940],
#         [-1.5826, -1.3948, -1.9143, -1.3816, -1.9103]],
#        grad_fn=<LogSoftmaxBackward0>)

# %% [markdown]
# ## Training
# ### DataLoaders and Batching
# Now we should build a generator that we can use to loop through our data. It'll be more efficient if we can pass our sequences in as batches. Our input tensors should look like `(sequence_length, batch_size)`. So if our sequences are 40 tokens long and we pass in 25 sequences, then we'd have an input size of `(40, 25)`.
#
# If we set our sequence length to 40, what do we do with messages that are more or less than 40 tokens? For messages with fewer than 40 tokens, we will pad the empty spots with zeros. We should be sure to **left** pad so that the RNN starts from nothing before going through the data. If the message has 20 tokens, then the first 20 spots of our 40 long sequence will be 0. If a message has more than 40 tokens, we'll just keep the first 40 tokens.

# %%
def dataloader(messages, labels, sequence_length=30, batch_size=32, shuffle=False):
    """ 
    Build a dataloader.
    """
    if shuffle:
        indices = list(range(len(messages)))
        random.shuffle(indices)
        messages = [messages[idx] for idx in indices]
        labels = [labels[idx] for idx in indices]

    total_sequences = len(messages)

    for ii in range(0, total_sequences, batch_size):
        batch_messages = messages[ii: ii+batch_size]
        
        # First initialize a tensor of all zeros
        batch = torch.zeros((sequence_length, len(batch_messages)), dtype=torch.int64)
        for batch_num, tokens in enumerate(batch_messages):
            token_tensor = torch.tensor(tokens)
            # Left pad!
            start_idx = max(sequence_length - len(token_tensor), 0)
            batch[start_idx:, batch_num] = token_tensor[:sequence_length]
        
        label_tensor = torch.tensor(labels[ii: ii+len(batch_messages)])
        
        yield batch, label_tensor

# %% [markdown]
# ### Training and  Validation
# With our data in nice shape, we'll split it into training and validation sets.

# %%
"""
Split data into training and validation datasets. Use an appropriate split size.
The features are the `token_ids` and the labels are the `sentiments`.
"""   

# TODO Implement 
split_percentage = 0.8
idx_split = int(len(token_ids) * split_percentage)

# Split out features/labels
train_features = token_ids[:idx_split]
valid_features = token_ids[idx_split:]
train_labels = sentiments[:idx_split]
valid_labels = sentiments[idx_split:]

# %%
text_batch, labels = next(iter(dataloader(train_features, train_labels, sequence_length=20, batch_size=64)))
model = TextClassifier(len(vocab)+1, 200, 128, 5, dropout=0.)
hidden = model.init_hidden(64)
logps, hidden = model.forward(text_batch, hidden)

# %% [markdown]
# ### Training
# It's time to train the neural network!

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = TextClassifier(len(vocab)+1, 1024, 512, 5, lstm_layers=2, dropout=0.2)
model.embedding.weight.data.uniform_(-1, 1)
model.to(device)
# Out:
# TextClassifier(
#   (embedding): Embedding(98411, 1024)
#   (lstm): LSTM(1024, 512, num_layers=2, dropout=0.2)
#   (dropout): Dropout(p=0.2, inplace=False)
#   (fc): Linear(in_features=512, out_features=5, bias=True)
#   (logsoftmax): LogSoftmax(dim=1)
# )

# %%
import numpy as np

# %%
"""
Train your model with dropout. Make sure to clip your gradients.
Print the training loss, validation loss, and validation accuracy for every 100 steps.
"""

epochs = 2
batch_size = 512
learning_rate = 0.001

sequence_length = 20
clip = 5 # gradient clipping

print_every = 100
criterion = nn.NLLLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

if(train_on_gpu):
    model.cuda()

model.train()

for epoch in range(epochs):
    print('Starting epoch {}'.format(epoch + 1))
    
    hidden = model.init_hidden(batch_size)
    
    steps = 0
    for text_batch, labels in dataloader(
            train_features, train_labels, batch_size=batch_size, sequence_length=sequence_length, shuffle=True):
        if text_batch.size() != torch.Size([sequence_length, batch_size]):
            continue
        
        steps += 1
        hidden = tuple([each.data for each in hidden])
        
        # Set Device
        text_batch, labels = text_batch.to(device), labels.to(device)
        for each in hidden:
            each.to(device)
            
        # TODO Implement: Train Model
        ## zero accumulated gradients
        model.zero_grad()
        
        ## get the output from the model
        logps, hidden = model(text_batch, hidden)
        
        ## calculate the loss and perform backprop
        loss = criterion(logps, labels)
        loss.backward()
        
        ## `clip_grad_norm` helps prevent the exploding gradient problem in RNNs / LSTMs.
        nn.utils.clip_grad_norm_(model.parameters(), clip)
        optimizer.step()
        
        # loss stats
        if steps % print_every == 0:
            model.eval()
            
            # Get validation loss
            val_h = model.init_hidden(batch_size)
            val_losses = []
            val_accuracy = []
            
            # valid_loader = DataLoader(valid_data, shuffle=True, batch_size=batch_size)
            for inputs, labels in dataloader(valid_features, valid_labels, batch_size=batch_size, sequence_length=sequence_length, shuffle=True):

                # If the size is different, we skip
                if inputs.size() != torch.Size([sequence_length, batch_size]):
                    continue

                # CPU or GPU                
                #if(train_on_gpu):
                #    inputs, labels = inputs.cuda(), labels.cuda()
                inputs, labels = inputs.to(device), labels.to(device)
                
                # Creating new variables for the hidden state, otherwise
                # we'd backprop through the entire training history
                #val_h = model.init_hidden(labels.shape[0]) # ensure size compatibility
                val_h = tuple([each.data for each in val_h])
                for each in val_h:
                    each.to(device)
               
                # Loss Calculation
                output, val_h = model.forward(inputs, val_h)
                val_loss = criterion(output.squeeze(), labels)
                val_losses.append(val_loss.item())
            
                # TODO: Calculate Accuracy
                ## See Practice: Part 8 - Transfer Learning
                ps = torch.exp(output)
                top_p, top_class = ps.topk(1, dim=1)
                equals = top_class == labels.view(*top_class.shape)
                val_accuracy.append(torch.mean(equals.type(torch.FloatTensor)).item())
            
            # TODO Implement: Print metrics
            
            model.train()
            
            print(
                "Epoch: {}/{}...".format(epoch+1, epochs),
                "Step: {}...".format(steps),
                "Loss: {:.5f}...".format(loss.item()),
                "Val Loss: {:.5f}".format(sum(val_losses) / len(val_losses)),
                'Val Accuracy: {:.6f}'.format(sum(val_accuracy) / len(val_accuracy))
            )
# Out:
# Starting epoch 1
# Epoch: 1/2... Step: 100... Loss: 1.07835... Val Loss: 1.02966 Val Accuracy: 0.586204
# Epoch: 1/2... Step: 200... Loss: 0.95157... Val Loss: 0.94255 Val Accuracy: 0.624321
# Epoch: 1/2... Step: 300... Loss: 0.93253... Val Loss: 0.88050 Val Accuracy: 0.657156
# Epoch: 1/2... Step: 400... Loss: 0.88440... Val Loss: 0.85441 Val Accuracy: 0.671982
# Epoch: 1/2... Step: 500... Loss: 0.88780... Val Loss: 0.83443 Val Accuracy: 0.677691
# Epoch: 1/2... Step: 600... Loss: 0.86510... Val Loss: 0.80993 Val Accuracy: 0.690258
# Epoch: 1/2... Step: 700... Loss: 0.80701... Val Loss: 0.79517 Val Accuracy: 0.697508
# Epoch: 1/2... Step: 800... Loss: 0.93082... Val Loss: 0.78859 Val Accuracy: 0.699451
# Epoch: 1/2... Step: 900... Loss: 0.84258... Val Loss: 0.77495 Val Accuracy: 0.702422
# Epoch: 1/2... Step: 1000... Loss: 0.78371... Val Loss: 0.77142 Val Accuracy: 0.703537
# Epoch: 1/2... Step: 1100... Loss: 0.80675... Val Loss: 0.76327 Val Accuracy: 0.708795
# Epoch: 1/2... Step: 1200... Loss: 0.81432... Val Loss: 0.75965 Val Accuracy: 0.709643
# Epoch: 1/2... Step: 1300... Loss: 0.83298... Val Loss: 0.75504 Val Accuracy: 0.712105
# Epoch: 1/2... Step: 1400... Loss: 0.82948... Val Loss: 0.74899 Val Accuracy: 0.714185
# Epoch: 1/2... Step: 1500... Loss: 0.81865... Val Loss: 0.74855 Val Accuracy: 0.714427
# Epoch: 1/2... Step: 1600... Loss: 0.85995... Val Loss: 0.74315 Val Accuracy: 0.715207
# Starting epoch 2
# Epoch: 2/2... Step: 100... Loss: 0.79591... Val Loss: 0.74689 Val Accuracy: 0.714272
# Epoch: 2/2... Step: 200... Loss: 0.69029... Val Loss: 0.74601 Val Accuracy: 0.715440
# Epoch: 2/2... Step: 300... Loss: 0.76971... Val Loss: 0.74893 Val Accuracy: 0.714727
# Epoch: 2/2... Step: 400... Loss: 0.82523... Val Loss: 0.74689 Val Accuracy: 0.714829
# Epoch: 2/2... Step: 500... Loss: 0.79356... Val Loss: 0.73882 Val Accuracy: 0.719525
# Epoch: 2/2... Step: 600... Loss: 0.80423... Val Loss: 0.73870 Val Accuracy: 0.717529
# Epoch: 2/2... Step: 700... Loss: 0.79909... Val Loss: 0.73702 Val Accuracy: 0.717645
# Epoch: 2/2... Step: 800... Loss: 0.76541... Val Loss: 0.73804 Val Accuracy: 0.715551
# Epoch: 2/2... Step: 900... Loss: 0.83337... Val Loss: 0.73516 Val Accuracy: 0.718600
# Epoch: 2/2... Step: 1000... Loss: 0.84135... Val Loss: 0.73337 Val Accuracy: 0.719370
# Epoch: 2/2... Step: 1100... Loss: 0.78440... Val Loss: 0.72764 Val Accuracy: 0.722365
# Epoch: 2/2... Step: 1200... Loss: 0.75741... Val Loss: 0.72718 Val Accuracy: 0.723029
# Epoch: 2/2... Step: 1300... Loss: 0.73003... Val Loss: 0.72838 Val Accuracy: 0.723010
# Epoch: 2/2... Step: 1400... Loss: 0.74855... Val Loss: 0.72585 Val Accuracy: 0.722918
# Epoch: 2/2... Step: 1500... Loss: 0.71798... Val Loss: 0.72487 Val Accuracy: 0.723684
# Epoch: 2/2... Step: 1600... Loss: 0.76429... Val Loss: 0.72335 Val Accuracy: 0.722642

# %% [markdown]
# ## Making Predictions
# ### Prediction
# Okay, now that you have a trained model, try it on some new twits and see if it works appropriately. Remember that for any new text, you'll need to preprocess it first before passing it to the network. Implement the `predict` function to generate the prediction vector from a message.

# %%
def predict(text, model, vocab):
    """ 
    Make a prediction on a single sentence.

    Parameters
    ----------
        text : The string to make a prediction on.
        model : The model to use for making the prediction.
        vocab : Dictionary for word to word ids. The key is the word and the value is the word id.

    Returns
    -------
        pred : Prediction vector
    """    
    
    # TODO Implement
    
    tokens = preprocess(text)
    
    # Filter non-vocab words
    tokens = [w for w in tokens if w in vocab]

    # Convert words to ids
    tokens = [vocab[w] for w in tokens]
        
    # Adding a batch dimension
    text_input = torch.tensor(tokens).unsqueeze(1)

    # Get the NN output
    hidden = model.init_hidden(text_input.size(1))
    logps, _ = model.forward(text_input, hidden)

    # Take the exponent of the NN output to get a range of 0 to 1 for each label.
    pred = torch.exp(logps)
    
    return pred

# %%
text = "Google is working on self driving cars, I'm bullish on $goog"
model.eval()
model.to("cpu")
predict(text, model, vocab)
# Out:
# tensor([[1.0429e-06, 7.8290e-05, 1.9853e-04, 5.0902e-01, 4.9070e-01]],
#        grad_fn=<ExpBackward0>)

# %% [markdown]
# ### Questions: What is the prediction of the model? What is the uncertainty of the prediction?
# Our goal is to determine the sentiment based on whether it is negative or positive.  Our 84% score indicates that the predicted sentiment, between 0 as negative and 1 as positive, highly indicates that the sentiment analysis is positive.

# %% [markdown]
# Now we have a trained model and we can make predictions. We can use this model to track the sentiments of various stocks by predicting the sentiments of twits as they are coming in. Now we have a stream of twits. For each of those twits, pull out the stocks mentioned in them and keep track of the sentiments. Remember that in the twits, ticker symbols are encoded with a dollar sign as the first character, all caps, and 2-4 letters, like $AAPL. Ideally, you'd want to track the sentiments of the stocks in your universe and use this as a signal in your larger model(s).
#
# ## Testing
# ### Load the Data

# %%
with open(os.path.join('..', '..', 'data', 'project_6_stocktwits', 'test_twits.json'), 'r') as f:
    test_data = json.load(f)

# %% [markdown]
# ### Twit Stream

# %%
def twit_stream():
    for twit in test_data['data']:
        yield twit

next(twit_stream())

# %% [markdown]
# Using the `prediction` function, let's apply it to a stream of twits.

# %%
def score_twits(stream, model, vocab, universe):
    """ 
    Given a stream of twits and a universe of tickers, return sentiment scores for tickers in the universe.
    """
    for twit in stream:

        # Get the message text
        text = twit['message_body']
        symbols = re.findall('\$[A-Z]{2,4}', text)
        score = predict(text, model, vocab)

        for symbol in symbols:
            if symbol in universe:
                yield {'symbol': symbol, 'score': score, 'timestamp': twit['timestamp']}

# %%
universe = {'$BBRY', '$AAPL', '$AMZN', '$BABA', '$YHOO', '$LQMT', '$FB', '$GOOG', '$BBBY', '$JNUG', '$SBUX', '$MU'}
score_stream = score_twits(twit_stream(), model, vocab, universe)

next(score_stream)

# %% [markdown]
# That's it. You have successfully built a model for sentiment analysis!

# %% [markdown]
# ## Submission
# Now that you're done with the project, it's time to submit it. Click the submit button in the bottom right. One of our reviewers will give you feedback on your project with a pass or not passed grade. You can continue to the next section while you wait for feedback.
