# %% [markdown]
# # AI for Trading | Module 6 | L13: Sentiment Prediction RNN

# %% [markdown]
# ## 1. Sentiment RNN, Introduction
# - https://youtu.be/bQWUuaMc9ZI
#
#
# ## 2. Pre-Notebook: Sentiment RNN
# Clone the repo from Github and open the notebook Sentiment_RNN_Exercise.ipynb in the sentiment-rnn folder. You can either download the repository with:
#
# ```
# git clone https://github.com/udacity/deep-learning-v2-pytorch.git
# ```
#
#
# ## 4. Data Pre-Processing
# - https://youtu.be/Xw1MWmql7no
#
#
# ## 5. Encoding Words, Solution
# - https://youtu.be/4RYyn3zv1Hg
#
#
# ## 6. Getting Rid of Zero-Length
# - https://youtu.be/Hs6ithuvDJg
#
#
# ## 7. Cleaning & Padding Data
# - https://youtu.be/UgPo1_cq-0g
#
#
# ## 8. Padded Features, Solution
# - https://youtu.be/sYOd1IDmep8
#
#
# ## 9. TensorDataset & Batching Data
# - https://youtu.be/Oxuf2QIPjj4
#
# ### Omission: shuffling data
# ![image.png](attachment:48833d5f-71c2-422c-b4f1-be298060767b.png)
#
#
# ## 10. Defining the Model
# - https://youtu.be/SpvIZl1YQRI

# %% [markdown]
# ## 11. Complete Sentiment RNN
# ### Complete RNN Class
# I know I want an embedding layer, a recurrent layer, and a final, linear layer with a sigmoid applied; I defined all of those in the __init__ function, according to passed in parameters.
#
# ![image.png](attachment:5fa5d83d-3cf4-479f-b5f2-c169f7fb8586.png)
#
# ### __init__ explanation
# ![image.png](attachment:f7cb1af8-2dc3-4f50-af9d-c6846eb8e6e7.png)
#
# ### Feedforward behavior
# ![image.png](attachment:0f11c45a-d00b-4d95-8df2-b41f4b394439.png)
#
# ### forward explanation
# ![image.png](attachment:871e379c-cdbd-4abd-a12b-1b09edf26e47.png)
#
# ### init_hidden
# ![image.png](attachment:47fb77a6-8d9c-4299-883e-f97484108c2d.png)
#
#
# ## 12. Training the Model
# ### Hyperparameters
# ![image.png](attachment:0921ac90-f171-455e-a23b-63b077718037.png)
#
# ### Training and Optimization
# ![image.png](attachment:9ef3ba23-7190-4214-8b9b-dd4b92f88d5e.png)
#
# ### Training Loop
# ![image.png](attachment:7f69c112-73fe-4037-a4af-3f8cce7c8d09.png)
# ![image.png](attachment:59aa9e31-5dac-4d0b-bbbe-36948fea390f.png)
# ![image.png](attachment:b3159816-0e11-4a2a-89b8-7dc825047ba0.png)
# ![image.png](attachment:ed31ee49-f67a-4234-9d3e-8251b314c2f8.png)
# ![image.png](attachment:74295e7d-eb3c-4454-bdc0-06b42532d39a.png)
#
# ### Consult the Solution Code
# To take a closer look at this solution, feel free to check out the solution workspace or [click here](https://github.com/udacity/deep-learning-v2-pytorch/blob/master/sentiment-rnn/Sentiment_RNN_Solution.ipynb) to see it as a webpage.

# %% [markdown]
# ## 13. Testing
# ### Testing the Trained Model
# ![image.png](attachment:9811144e-1735-453d-b55f-6ee254e3ce00.png)
# ![image.png](attachment:c391979a-2d11-4f11-8998-0d33395bbdd3.png)
# ![image.png](attachment:5c0c8d35-2f04-42d0-aead-0d0a2a59eb1f.png)
#
# ### Exercise: Inference on a test review
# ![image.png](attachment:c15192c6-ff0d-4784-a796-092660c6ef30.png)

# %% [markdown]
# ## 14. Inference, Solution
# ### Inference
# ![image.png](attachment:09ae996c-1127-441e-8d77-16fc00b53d93.png)
#
# ### Pre-process the test_review
# ![image.png](attachment:4da83627-5215-46f0-827c-9147e84d5524.png)
#
# ### Padding and converting into a Tensor
# ![image.png](attachment:12fb8055-735c-4c2e-9cda-6cd42fb9f5be.png)
# ![image.png](attachment:6655f783-7cc3-4376-9c5a-5949d09fa3e1.png)
#
# ### Conclusion
# ![image.png](attachment:9375dbef-8f4e-432d-9627-70c7b7b5b9fc.png)
