# %% [markdown]
# # AI for Trading | Module 6 | L09: Training Neural Networks

# %% [markdown]
# ## 3. Testing
# - https://youtu.be/EeBZpb-PSac
#
#
# ## 4. Overfitting and Underfitting
# - https://youtu.be/xj4PlXMsN-Y
#   - Underfitting vs Overfitting
#   - ![image.png](attachment:a2aea404-d9b9-4ac1-8f05-b95985404e68.png)
#   - ![image.png](attachment:74f575d6-fdcd-45d4-9b68-dc9e4a00e364.png)
#   -
#
# ## 5. Early Stopping
# - https://youtu.be/NnS0FJyVcDQ
#   - ![image.png](attachment:e6b929f9-48a0-4d60-afcd-41049a157985.png)
#   - Model Complexity Graph
#   - ![image.png](attachment:c7c054ec-2d85-453d-9cfc-9e9545dca7b3.png)
#
#
# ## 6. Regularization
# - https://youtu.be/KxROxcRsHL8
#
#
# ## 7. Regularization 2
# - https://youtu.be/ndYnUrx8xvs
#   - ![image.png](attachment:313de991-47da-481c-9c2c-2f323174d656.png)
#   - ![image.png](attachment:69e301d8-3684-4336-9999-47ae943e8177.png)
#
#
# ## 8. Dropout
# - https://youtu.be/Ty6K6YiGdBs
#   - Turn off a node so that it doesn't dominate the training process.
#
#
# ## 9. Local Minima
# - https://youtu.be/gF_sW_nY-xw
#   - Gradient Descent gets stuck at a point where it thinks its the lowest when it hasn't seen the next lowest hump as shown in the following picture.
#   - ![image.png](attachment:257a79e2-bcf1-4109-aca4-2dfb8e32ebca.png)
#
#
# ## 10. Random Restart
# - https://youtu.be/idyBBCzXiqg
#   - Start from random locations and do Gradient Descent from them.
#
#
# ## 11. Vanishing Gradient
# - https://youtu.be/W_JJm_5syFw
#   - How do we take larger steps because using derivatives in each perceptron become even more tinier.
#
#
# ## 12. Other Activation Functions
# - https://youtu.be/kA-1vUt6cvQ
#   - Hyperbolic Tangent Function
#   - 0:30: Rectified Linear Unit (ReLU)
#   - We could use these alternative activation functions to have a larger output for larger Gradient Descents
#
#
# ## 13. Batch vs Stochastic Gradient Descent
# - https://youtu.be/2p58rVgqsgo
#   - 1:32 Stochastic Gradient Descent
#   - Instead of doing 1 whole Gradient Descent step, we can bundle up several to create several bundled Gradient Descent called Stochastic Gradient Descent.
#
#
# ## 14. Learning Rate Decay
# - https://youtu.be/TwJ8aSZoh2U
#   - ![image.png](attachment:1fc8ecc6-5bf0-4e66-9595-c062dd34bbb3.png)
#
#
# ## 15. Momentum
# - https://youtu.be/r-rYz_PEWC8
#   - ![image.png](attachment:939e6ac8-491b-4046-842e-01da98b64fab.png)
#
# ### Resources
# - DeepLearning.ai: https://youtu.be/k8fTYJPd3_I
#
#
# ## 16. Error Functions Around the World
# - https://youtu.be/34AAcTECu2A
#   -
