# %% [markdown]
# # AI for Trading | Module 6 | L10: Deep Learning with PyTorch

# %% [markdown]
# ## 1. Welcome
#
# ![image.png](attachment:7b045b9d-da44-4cba-943c-5c2d6379c640.png)
#
# Hi, I'm Mat!
# Welcome!
#
# Welcome! In this lesson, you'll learn how to use PyTorch for building deep learning models. PyTorch was released in early 2017 and has been making a pretty big impact in the deep learning community. It's developed as an open source project by the Facebook AI Research team, but is being adopted by teams everywhere in industry and academia. In my experience, it's the best framework for learning deep learning and just a delight to work with in general. By the end of this lesson, you'll have trained your own deep learning model that can classify images of cats and dogs.
#
# I'll first give you a basic introduction to PyTorch, where we'll cover tensors - the main data structure of PyTorch. I'll show you how to create tensors, how to do simple operations, and how tensors interact with NumPy.
#
# Then you'll learn about a module called autograd that PyTorch uses to calculate gradients for training neural networks. Autograd, in my opinion, is amazing. It does all the work of backpropagation for you by calculating the gradients at each operation in the network which you can then use to update the network weights.
#
# Next you'll use PyTorch to build a network and run data forward through it. After that, you'll define a loss and an optimization method to train the neural network on a dataset of handwritten digits. You'll also learn how to test that your network is able to generalize through validation.
#
# However, you'll find that your network doesn't work too well with more complex images. You'll learn how to use pre-trained networks to improve the performance of your classifier, a technique known as transfer learning.
#
# Follow along with the videos and work through the exercises in your own notebooks. If you get stuck, check out my solution videos and notebooks.
#
# ### Get Notebooks
# All notebooks for this section is available to be cloned:
# ```
# git clone https://github.com/udacity/deep-learning-v2-pytorch.git
# ```
#
#
# ## 4. Single layer neural networks
# - https://youtu.be/6Z7WntXays8
#
#
# ## 5. Single layer neural networks solution
# - Solution: https://youtu.be/mNJ8CujTtpo
#
#
# ## 6. Networks Using Matrix Multiplication
# - Solution: https://youtu.be/QLaGMz8Ca3E
#
#
# ## 7. Multilayer Networks Solution
# - Solution: https://youtu.be/iMIo9p5iSbE
#
#
# ## 8. Neural Networks in PyTorch
# - https://youtu.be/CSQOdOb2mlg
#
#
# ## 9. Neural Networks Solution
# - https://youtu.be/zym36ihtOMY

# %%
## 10. Implementing Softmax Solution
'''
- https://youtu.be/8KRX7HvqfP0
- work/t2-ai-algorithms-in-trading/project-6-sentiment-analysis-with-neural-networks/notes/c2-m6-l10-dep-learning-pytorch.ipynb

'''

def softmax(x):
    ## TODO: Implement the softmax function here
    return torch.exp(x) / torch.sum(torch.exp(x), dim=1).view(-1, 1)

# %% [markdown]
# ## 11. Network Architectures in PyTorch
# - https://youtu.be/9ILiZwbi9dA
# - work/t2-ai-algorithms-in-trading/project-6-sentiment-analysis-with-neural-networks/practices/c2-m6-l10-deep-learning-pytorch/Part 3 - Training Neural Networks (Exercises).ipynb
#
#
# ## 12. Network Architectures Solution
# - https://youtu.be/zBWlOeX2sQM
# - work/t2-ai-algorithms-in-trading/project-6-sentiment-analysis-with-neural-networks/practices/c2-m6-l10-deep-learning-pytorch/Part 3 - Training Neural Networks (Exercises).ipynb
#
#
# ## 13. Training a Network Solution
# - https://youtu.be/ExyFG2MjsKs
# - work/t2-ai-algorithms-in-trading/project-6-sentiment-analysis-with-neural-networks/practices/c2-m6-l10-deep-learning-pytorch/Part 3 - Training Neural Networks (Exercises).ipynb
#
#
# ## 14. Classifying Fashion-MNIST
# - https://youtu.be/AEJV_RKZ7VU
#
#
# ## 15. Fashion-MNIST Solution
# - https://youtu.be/R6Y4hPLVQWM
#
#
# ## 16. Inference and Validation
# - https://youtu.be/XACXlkIdS7Y
#
#
# ## 17. Validation Solution
# - https://youtu.be/AjrXltxqsK4
#
#
# ## 18. Dropout Solution
# - https://youtu.be/3Py2SbtZLbc
#
#
# ## 19. Saving and Loading Models
# - https://youtu.be/psmrPu-mseA
#
#
# ## 20. Loading Image Data
# - https://youtu.be/hFu7GTfRWks
# - work/t2-ai-algorithms-in-trading/project-6-sentiment-analysis-with-neural-networks/practices/c2-m6-l10-deep-learning-pytorch/Part 7 - Loading Image Data (Exercises).ipynb
#
#
# ## 21. Loading Image Data Solution
# - https://youtu.be/d_NhvI1yEf0
#
#
# ## 24. Transfer Learning II
# - https://youtu.be/S9F7MtJ5jls
#
#
# ## 26. Tips, Tricks, and Other Notes
# ![image.png](attachment:04717686-835e-41bb-99d6-be9d81dc88ee.png)
