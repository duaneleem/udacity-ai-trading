# %% [markdown]
# # AI for Trading | Module 6 | L08: Introduction to Neural Networks

# %% [markdown]
# ## 1. Instructor
# ![image.png](attachment:f6ab72e5-56e7-4791-880b-1071c7499b70.png)
#
# Luis Serrano
#
# Hello and welcome to Introduction to Neural Networks, given by Luis!
#
# Luis was formerly a Machine Learning Engineer at Google. He holds a PhD in mathematics from the University of Michigan, and a Postdoctoral Fellowship at the University of Quebec at Montreal.
#
#
# ## 2. Introduction
# - https://youtu.be/tn-CrUTkCUc
#
#
# ## 3. Classification Problems 1
# - https://youtu.be/Dh625piH7Z0
#
#
# ## 4. Classification Problems 2
# - https://youtu.be/46PywnGa_cQ
#
#
# ## 5. Linear Boundaries
# - https://youtu.be/X-uMlsBi07k
#
# ![image.png](attachment:c5281c31-fe9f-4f92-aa9d-b29ff90db1ab.png)
#
# Test: 7, Grade: 6
# 2(7) + 6 - 18
# 14 + 6 - 18 = 2
#
#
# ## 6. Higher Dimensions
# - https://youtu.be/eBHunImDmWw
#   - x1 test, x2 grades, x3 class rank
#
# ![image.png](attachment:3c2876b4-c4b0-4ce0-af64-ed6d8e38954e.png)
# ![image.png](attachment:b607bf26-7d91-43c9-a6cf-dc50509ef4df.png)
#
#
# ## 7. Perceptrons
# - https://youtu.be/hImSxZyRiOw
#   - 0:55 Plots points if in the positive or negative area. If positive, it's in the "yes" area, otherwise "no" area.
#   - 3:07 Step Function: y=1 if x >= 0; y=0 if x<0
#   - ![image.png](attachment:ddd0a443-e437-449e-a9ae-6d394ab5046e.png)
#
# ### Quiz
# Given Score = 2*Test + 1*Grade - 18, suppose w1 was 1.5 instead of 2. Would the student who got 7 on the test and 6 on the grades be accepted or rejected?
#
# (1.5 * 7) + (1 * 6) - 18
# 10.5 + 6 - 18
# -1.5
# Results: Rejected
#
#
# ## 8. Why "Neural Networks"?
# - https://youtu.be/zAkzOZntK6Y
#   - ![image.png](attachment:6b14394d-cfde-4618-aa98-5a871569d8b2.png)
#
#
# ## 9. Perceptrons as Logical Operators
# - https://youtu.be/Y-ImuxNpS40
#   - ![image.png](attachment:bb94ed80-bd80-492a-bf3c-49a3975c8c17.png)
#
# ### Practices
# - Need explanation about formulating weights (W).
#   - Boundary Line equation: w1x1 + w2x2 + b = 0
# - Revisit for understanding
# - Additional explanation
#   - https://www.youtube.com/watch?v=-KLnurhX-Pg
#
# #### Quiz 2
# ![image.png](attachment:ba288268-6db4-4e96-84e5-f4d0cb14cd8e.png)
#
# #### Quiz: Build an XOR Multi-Layer Perceptron
# Now, let's build a multi-layer perceptron from the AND, NOT, and OR perceptrons to create XOR logic!
#
# The neural network below contains 3 perceptrons, A, B, and C. The last one (AND) has been given for you. The input to the neural network is from the first node. The output comes out of the last node.
#
# The multi-layer perceptron below calculates XOR. Each perceptron is a logic operation of AND, OR, and NOT. However, the perceptrons A, B, and C don't indicate their operation. In the following quiz, set the correct operations for the perceptrons to calculate XOR.
#
# ![image.png](attachment:c013c43f-226b-4a3b-a12e-8d37d57baf14.png)
#
#
# ## 10. Perceptron Trick
# In the last section you used your logic and your mathematical knowledge to create perceptrons for some of the most common logical operators. In real life, though, we can't be building these perceptrons ourselves. The idea is that we give them the result, and they build themselves. For this, here's a pretty neat trick that will help us.
#
# - https://youtu.be/-zhTROHtscQ
# - https://youtu.be/fATmrG2hQzI
# - https://youtu.be/lif_qPmXvWA
#
# ### Notes
# - We'll be using "learning rates" that will give miscalculated points the chance to correct the regression line.
#
#
# ## 11. Perceptron Algorithm
# And now, with the perceptron trick in our hands, we can fully develop the perceptron algorithm! The following video will show you the pseudocode, and in the quiz below, you'll have the chance to code it in Python.
# - https://youtu.be/p8Q3yu9YqYk

# %%
import numpy as np
# Setting the random seed, feel free to change it and see different solutions.
np.random.seed(42)

def stepFunction(t):
    if t >= 0:
        return 1
    return 0

def prediction(X, W, b):
    return stepFunction((np.matmul(X,W)+b)[0])

# TODO: Fill in the code below to implement the perceptron trick.
# The function should receive as inputs the data X, the labels y,
# the weights W (as an array), and the bias b,
# update the weights and bias W, b, according to the perceptron algorithm,
# and return W and b.
def perceptronStep(X, y, W, b, learn_rate = 0.01):
    # Fill in code
    for i in range(len(X)):
        y_hat = prediction(X[i],W,b)
        if y[i]-y_hat == 1:
            W[0] += X[i][0]*learn_rate
            W[1] += X[i][1]*learn_rate
            b += learn_rate
        elif y[i]-y_hat == -1:
            W[0] -= X[i][0]*learn_rate
            W[1] -= X[i][1]*learn_rate
            b -= learn_rate
    return W, b
    
# This function runs the perceptron algorithm repeatedly on the dataset,
# and returns a few of the boundary lines obtained in the iterations,
# for plotting purposes.
# Feel free to play with the learning rate and the num_epochs,
# and see your results plotted below.
def trainPerceptronAlgorithm(X, y, learn_rate = 0.01, num_epochs = 25):
    x_min, x_max = min(X.T[0]), max(X.T[0])
    y_min, y_max = min(X.T[1]), max(X.T[1])
    W = np.array(np.random.rand(2,1))
    b = np.random.rand(1)[0] + x_max
    # These are the solution lines that get plotted below.
    boundary_lines = []
    for i in range(num_epochs):
        # In each epoch, we apply the perceptron step.
        W, b = perceptronStep(X, y, W, b, learn_rate)
        boundary_lines.append((-W[0]/W[1], -b/W[1]))
    return boundary_lines
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-80a3f855a964> in <module>()
# ----> 1 import numpy as np
#       2 # Setting the random seed, feel free to change it and see different solutions.
#       3 np.random.seed(42)
#       4
#       5 def stepFunction(t):
#
# ModuleNotFoundError: No module named 'numpy'

# %% [markdown]
# ## 12. Non-Linear Regions
# - https://youtu.be/B8UrWnHh1Wc
#
# ![image.png](attachment:6d5db1ad-58ea-437b-8c01-f84d1fa6bca5.png)
# ![image.png](attachment:08506bfe-a6dc-4145-beae-96d69615b45a.png)
#
#
# ## 13. Error Functions
# - https://youtu.be/YfUUunxWIJw
#
#
# ## 14. Log-loss Error Function
# - https://youtu.be/jfKShxGAbok
#   - 1:00 Gradient Descent
#
# ### Quiz
# ![image.png](attachment:3baa9608-450a-4cdf-b80e-e6e4fcdf7d49.png)
#
#
# ## 15. Discrete vs Continuous
# In the last few videos, we learned that continuous error functions are better than discrete error functions, when it comes to optimizing. For this, we need to switch from discrete to continuous predictions. The next two videos will guide us in doing that.
#
# - https://youtu.be/rdP-RPDFkl0
# - https://youtu.be/Rm2KxFaPiJg
#   - ![image.png](attachment:a8e376de-a48c-456b-a9ac-017e13eedec3.png)
#   - ![image.png](attachment:4d1ee4c4-ad8d-4713-823f-5244b04f3861.png)
#   - 3:20 ![image.png](attachment:1e477af0-0a7d-4f66-8038-04ce9686904d.png)
#   - Understand: Perceptron Activator: Step Function vs Sigmoid Function?
#   - Understand: What is sigmoid function?
#     - Math: Logistic Regression
#     - https://youtu.be/TPqr8t919YM
#
# ### Quiz
# ![image.png](attachment:5c0fd178-e519-4c9d-af6d-d932fb7c7cfb.png)
#
#
# ## 16. Softmax
# - https://youtu.be/NNoezNnAMTY
#
# ### The Softmax Function
#
# In the next video, we'll learn about the softmax function, which is the equivalent of the sigmoid activation function, but when the problem has 3 or more classes.
#
# https://youtu.be/RC_A9Tu99y4
#
# ### Quiz 1
# - ![image.png](attachment:71e204fa-418d-4b30-9275-f7ecfc4c1ae1.png)
#   - Answer: https://youtu.be/n8S-v_LCTms
