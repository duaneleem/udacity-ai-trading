# %% [markdown]
# # AI for Trading | Module 7 | L18: Random Forests
# ## 1. Intro
# https://youtu.be/lSJ3XajG1L8

# %% [markdown]
# ## 2. Review Random Forests
# ![image.png](attachment:267c8e1c-7877-4e6a-8252-2294e9539536.png)
#
#
# ## 3. Setup Code Exercise
# https://youtu.be/xlwlc6l7pXg
#
#
# ## 5. Universal Quant Features
# https://youtu.be/R8kfSvnHA3k
#
# ### Optional Walk-through of the code
# The videos below walk through the coding exercise in small parts, followed by videos that live code the solutions. Depending on your preference, you may either walk through the videos as you work on the code exercises, or you may also skip the videos and just read the notebook. You may also choose to watch the videos by themselves, as they will also cover the solutions. I'd love to hear about what approach works for you (you can let us know in the lesson feedback). Thanks! -Eddy
#
# ### Volatility and dollar volume code intro
# https://youtu.be/H5hJOG1DjBU
# https://youtu.be/1WK5VAMzQ2Q
# https://youtu.be/xwBdEXXTu1s
#
# ### Volatility and Dollar Volume Solution
# https://youtu.be/FBOlA2NaK3k
#
#
# ## 6. Market Dispersion
# - https://youtu.be/x7ON_-QrpHQ
# - Market Disperion looks cross-section of stocks and how spread out they are.
#
# ### Market Dispersion Code Intro (Optional)
# - https://youtu.be/xCGuuymx180
# - https://youtu.be/waeV2fKGeW8
#
# ### Market Dispersion Solution (Optional)
# https://youtu.be/S5lzU1nAuhU
#
#
# ## 7. Market Volatility
# - https://youtu.be/cHU7Sh12eOo
# - Market Volatility is the volatility of the stock universe over a time horizon.
#
# ### Market Volatility Code Intro (Optional)
# - https://youtu.be/G03W42Z5RSo
# - https://youtu.be/yR1eWiv1jTM
#
#
# ## 8. Sector
# - https://youtu.be/Q5CZxxKXAB8
#
#
# ### Sector Code Intro (Optional)
# - https://youtu.be/NSp_qX8s_B0
# - https://youtu.be/DmYfsKS6kRM
# - https://youtu.be/sywFquETqso
# - https://youtu.be/I9iFbxzIu60
