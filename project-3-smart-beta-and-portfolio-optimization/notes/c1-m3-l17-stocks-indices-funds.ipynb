# %% [markdown]
# # AI for Trading | Module 3 | L17: Stocks, Indices, Funds

# %% [markdown]
# ## 2. Intro
# ### Stocks
# - https://youtu.be/XHo5iyxDxOQ
#   - 0:14 Equity = Assets - Liabilities
#   - Stock or Shares represent partial ownership of a company’s equity.
#
# ## 3. Indices
# - https://youtu.be/BRv5B78YBGs
#   - 0:00 Index Examples
#     - S&P: Standard and Poor’s 500 Index (USA)
#     - Dow: Dow Jones Industrial Average (USA)
#     - IBOVESPA: Ibovespa Brasil Sao Paulo Stock Exchange Index (Brazil)
#     - MERVAL: Buenos Aires Stock Exchange Merval Index (Argentina)
#     - NIKKEI: Nikkei 225 Index (Japan) HANG SENG: Hang Seng Composite Index (Hong Kong)
#     - FTSE 100: Financial Times Stock Exchange 100 Index (UK)
#     - EURO STOXX: EURO STOXX 50 (Europe)
#   - 1:10 Index: Aggregated value of a group of stocks company's equity
# - https://youtu.be/oAd_szbBNWc
#   - 0:00 Indices are not actual funds that people invest in.
#   - They represent the aggregated performance of a collection of stocks.
# - https://youtu.be/jNzwxE3el7I
#   - Indices Describe the Market
#     - Indices track subgroups of the market, and may be designed specifically to track stocks in the same stock exchange, same country, or same sector.
#     - Indices give investors a measure of the market’s status.
#     - Professional investment managers may use indices as benchmarks against which they can evaluate their own fund’s performance.
#
# ## 4. Market Cap
# - https://youtu.be/PE0UgUc0f0U
#   - 0:30 Market Capitalization
#     - Large Cap
#     - Mid Cap
#     - Small Cap
#
# ## 5. Growth V. Value
# - https://youtu.be/ZCjre5YTD0s
#   - 0:08 Growth Stock: Growth in sales, revenue, earnings
#   - 0:30 Stable sales, revenue, earnings
#
# ## 6. Ratios
# - https://youtu.be/Dfbwep-tkok
#   - 0:00 Ratios
#     - Price to Earnings
#     - Price to Sales
#     - Prices to Book
#   - 1:00 Growth Stocks: High Ratios
#   - Value Stocks: Low Ratios
#
# ## 7. Index Categories
# - https://youtu.be/D3VGIvti71g
# - Indices are created as subsets of other indices. One way of creating subsets include categorizing by market cap, and then value vs. growth. This is how Standard and Poor’s breaks down some of its indices:
#   - S&P 500
#     - S&P 500 Growth
#     - S&P 500 Value
#   - S&P MidCap 400
#     - S&P MidCap 400 Growth
#     - S&P MidCap 400 Value
#   - S&P SmallCap 600
#     - S&P SmallCap 600 Growth
#     - S&P SmallCap 600 Value
#
# ## 8. Price Weighting
# - https://youtu.be/2SFbwJ19NhA
# - ![image.png](attachment:6fbabb0e-3067-4c6f-8f6e-139226146c38.png)
#
# ## 9. Market Cap Weighting
# - https://youtu.be/7qVVA5yLFnY
#   - 0:20 Market Cap Weighted Indices
#     - Market cap = number of shares x price per share
#   - 1:00 Market Cap Weighted Indices
#     - S&P 500
#     - IBOVESPA
#     - MERCAL
#     - HANG SENG
#     - FTSE
#     - EURO STOXX
#
# ### Quiz
# A market cap weighted index has two stocks, A and B. Stock A has 3 million shares at $5 per share. Stock B has 10 million shares at $2 per share. What are the weights of stock A and B in the portfolio?
#
# Stock A: 15 million (43%)
# Stock B: 20 million (57%)
# Total: 35 million
#
#
# ## Adding or Removing from an Index
# - https://www.youtube.com/watch?v=_bWIZWa20j8&t=1s
#   - 0:30 Monsanto out (Index delete)
#   - Twitter in (Index add)
#
#
# ## 11. How an Index is Constructed
# - https://youtu.be/dsbi4dvdU9c
#   - 0:38 Total Market Cap = Sum of individual market caps
#   - Hang Seng Index
#     - ![image.png](attachment:77b41edb-76fa-46e4-a577-ca45a8423504.png)
#
# ### Quiz
# ```
# Day 1: 100 + 200 = 300
# Day 2: 105 + 210 = 315
# 315 / 300 = 1.05
# Day 2 index: 100 * 1.05 = 105
# ```
#
# ### Quiz Answer:
# ```
# On day 1, the total market cap is $100 + $200 = $300 million.
# One month later, the total market cap is $105 + $210 = $315 million.
# The percent change in market cap over a month is 315/300 -1, or 5%.
# Adding 5% to the index of 100 points is 105 points.
# ```
#
# ## 12. Hang Seng Index Construction
# - https://youtu.be/rdGdC-meRLU
#
# ### Free Float
# ```
# - Free float shares refers to the number of shares that are liquid and tradable on the stock exchange.
# - Free float shares may be considered a better measure when calculating market cap because only free float shares can be bought or sold, which means only the trade of free float shares affects the market movement of the stock.
# ```
#
# ### Capped Index
# ```
# Now let’s define a capped index. First of all, the English is a bit funny in that the word “cap” that we’re using here has a different meaning from market cap. The “cap” in this context is similar to the concept of putting a cap on a cookie jar, or putting a cap on your daily spending on cookies. It refers to setting a maximum limit.
#
# Tencent holding has a market capitalization of 4 trillion hong kong dollars, while the market capitalization of all companies in the Hang Seng Index, including Tencent, is about 20 trillion. So Tencent actually accounts for about 4 divided by 20, or 20% of the value of these 50 companies. An index that tries to keep large companies from dominating the index is called a capped index, because it sets a maximum weight that can be assigned to a single company. In the case of the Hang Seng Index, the largest allowed weight assigned to any single company is 15% so Tencent is assigned a weight of 15% and not 20%.
# ```
#
#
# ## 13. Index after Add or Delete
# - https://youtu.be/hiAHRE6JY0k
#
#
# ## 14. Funds
# - https://youtu.be/s9f2Bzc9lnk
#   - 0:00 Professionally managed portfolio of investor money.
#   - 0:22 Diversification: improve risk versus return (Sharpe Ratio)
#   - 1:20 Sharpe Ratio: return vs risk
#
#
# ## 15. Active vs Passive
# - https://youtu.be/QzoHmUzJ5zw
#   - 0:33 Index Fund = Passively managed fund that tracks and index
#   - Actively Managed Fund: seeks to outperform its benchmark (such as an index).
#   - Passively Managed Fund: seeks to track its benchmark (such as an index).
#   - Note: passively managed funds that track an index are also referred to ask “index funds”. An index fund is a fund, not an index.
# - https://youtu.be/CcVdfrr5nD8
#   - 0:29 Excess return = portfolio return - risk free rate
#   - ![image.png](attachment:8ba1ca66-c783-47f9-bbb6-80a43c6c6af7.png)
#   - ![image.png](attachment:58ea8e82-4a1a-4e5d-b0f5-f18b89fd8c5d.png)
#   - Actively Managed funds are also referred to as “alpha” funds.
#   - Passively Managed funds are likewise referred to as “Beta” funds.
#
#
# ## 17. Smart Beta
# - https://youtu.be/Rc9NEmNMzk8
#   -
