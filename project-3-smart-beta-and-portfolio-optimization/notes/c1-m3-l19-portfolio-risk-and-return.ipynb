# %%
# AI for Trading | Module 3 | L19: Portfolio Risk and Return

# %% [markdown]
# ## 2. Diversification
# - https://youtu.be/tyzqlXddXd8
#
#
# ## 3. Portfolio Mean
# - https://youtu.be/vozlctvug7I
#   - 1:04 ![image.png](attachment:6e68ad8c-7f4e-44e0-a4f7-5ba133324497.png)
#   - 1:10 ![image.png](attachment:4aacccb2-c575-4249-b3dc-49352bd04aec.png)
#   - ![image.png](attachment:26c0dc0e-9a59-4e4b-bef7-374471696c45.png)
#
#
# ## 4. Portfolio Variance
# - https://youtu.be/LlxRypakop4
#   - 0:25 ![image.png](attachment:682884f4-835f-4f6a-bc43-1c6cb75dcd6a.png)
#   -
#   - ![image.png](attachment:a025c0f4-3927-47bd-b7b9-11ac8604a495.png)
#
#
# ## 5. Reducing Risk
# Reducing Risk with Imperfectly Correlated Stocks
# ![image.png](attachment:e8339c9e-97e0-4424-8bd2-a1d624b16470.png)
#
#
# ## 6. Variance of a 3-Asset Portfolio
# ![image.png](attachment:8909fc9b-0d16-4f6e-873f-c1facb40b3b5.png)
# ![image.png](attachment:cffae32d-4987-48dd-9b43-468b3da7cdcf.png)
